# %%
# 匯入套件
# !pip install lxml
from bs4 import BeautifulSoup as bs
import lxml
import requests as req
from pprint import pprint
# Out:
# Requirement already satisfied: lxml in /usr/local/python/3.10.13/lib/python3.10/site-packages (5.1.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python -m pip install --upgrade pip

# %% [markdown]
# # 一般用法
# ---

# %%
# Out:
#   Cell In[14], line 2
#     base_url = "https://www.ptt.cc/bbs/
#                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# 取得新聞列表
base_url = "https://www.ptt.cc/bbs/"
index_page = "/index.html" 

pages_to_visit = ["home-sale","NBA","Lifeismoney"]

# 用 requests 的 get 方法把網頁抓下來
for section in pages_to_visit:
    url = base_url + section + index_page
    res = req.get(url) 

    # 指定 lxml 作為解析器
    soup = bs(res.text, "lxml") 

    # 建立 list 來放置列表資訊
    list_posts = []
    # 清空放置列表資訊的變數
    list_posts.clear()
    # 取得 列表 的文字與超連結
    for a in soup.select('div.r-ent div.title a[href]'):
        print(a.get_text())
        print(a['href']) # 或是 a.get('href') 
        
        # 加入列表資訊
        list_posts.append({
            'title': a.get_text(),
            'link': 'https://www.ptt.cc' + a['href']
        })
# Out:
# Re: [新聞] 台南房價繼續衝 「湖美帝璟」Q3開6字頭銷
# /bbs/home-sale/M.1707015819.A.F5E.html
# [請益] 立信天朗居住環境
# /bbs/home-sale/M.1707018611.A.29D.html
# Re: [心得] 該回防蛋黃區了
# /bbs/home-sale/M.1707019406.A.9C7.html
# [閒聊] 遲來的盒盒道歉文～
# /bbs/home-sale/M.1707019709.A.298.html
# [社區] 台中烏日 高鐵之星
# /bbs/home-sale/M.1707021560.A.DEE.html
# [閒聊] 廁所不開窗是主流嗎
# /bbs/home-sale/M.1707022235.A.A68.html
# [賣/台中/烏日] 高鐵之星大兩房平面車位
# /bbs/home-sale/M.1707023164.A.683.html
# Re: [閒聊] 遲來的盒盒道歉文～
# /bbs/home-sale/M.1707026851.A.FAD.html
# [新聞] 日經：中國空屋可再容納1.5億人 去庫存
# /bbs/home-sale/M.1707030097.A.4EA.html
# [請益] 夫妻購屋貸款問題
# /bbs/home-sale/M.1707031899.A.720.html
# [買/雙北/多區] 公寓，套房，華夏
# /bbs/home-sale/M.1707036647.A.6D9.html
# Re: [新聞] 日經：中國空屋可再容納1.5億人 去庫存
# /bbs/home-sale/M.1707038919.A.680.html
# [請益] 社宅一萬塊修繕補助用在哪CP值最高
# /bbs/home-sale/M.1707039098.A.01F.html
# [新聞] 小宅是主流？專家揭每6間有1間空屋 「小
# /bbs/home-sale/M.1707042025.A.310.html
# [閒聊] 有人看落架也會看到興奮嗎？
# /bbs/home-sale/M.1707042374.A.870.html
# [新聞] 【高雄】岡山捷運建設與商圈成長 南岡山
# /bbs/home-sale/M.1707044912.A.B05.html
# [公告] 版務公約
# /bbs/home-sale/M.1700486631.A.A60.html
# [閒聊] 我整理了2023第三季 六都房價圖表
# /bbs/home-sale/M.1702532990.A.DDB.html
# [公告] 2024.01月置底版務、檢舉文
# /bbs/home-sale/M.1704955981.A.7B6.html
# [公告] 新增版務公約
# /bbs/home-sale/M.1705220294.A.146.html
# [花邊] Thibodeau：LeBron打了41分鐘，要讚揚他
# /bbs/NBA/M.1707036477.A.838.html
# [發錢] 新板主最後希望
# /bbs/NBA/M.1707037879.A.A9D.html
# [情報] Woj: Jarred Vanderbilt 右腳傷勢嚴重
# /bbs/NBA/M.1707040462.A.A5D.html
# [公告] 板規10.1
# /bbs/NBA/M.1669686360.A.504.html
# [情報] 2023-24賽季 例行賽賽程 (一月、二月上半)
# /bbs/NBA/M.1703474570.A.5DA.html
# [公告] 明星賽期板主徵選
# /bbs/NBA/M.1705632851.A.439.html
# [情報] NBA Standings (Feb. 04, 2024)
# /bbs/NBA/M.1707020302.A.0DC.html
# [公告] NBA 板 開始舉辦樂透!
# /bbs/NBA/M.1707020589.A.928.html
# [情報] 飛利浦官網電動牙刷HX2411送5刷頭1499
# /bbs/Lifeismoney/M.1706928517.A.28A.html
# Re: [情報] 無印良品大放送選到店免費
# /bbs/Lifeismoney/M.1706929937.A.DE4.html
# [情報] line禮物 85度c優惠券
# /bbs/Lifeismoney/M.1706937033.A.CB9.html
# [情報] openpoint 咖啡廣場調和式冰咖啡 10p
# /bbs/Lifeismoney/M.1706941426.A.039.html
# [情報] Line 禮物 指定蛋糕399-100
# /bbs/Lifeismoney/M.1706946622.A.CED.html
# [情報] 肯德基優惠碼 13573 / 2雞+2塔 119
# /bbs/Lifeismoney/M.1706952227.A.988.html
# [情報] 5th牛仔褲特價390元
# /bbs/Lifeismoney/M.1706955873.A.C52.html
# [情報] Google play 點數 600
# /bbs/Lifeismoney/M.1706956767.A.6F5.html
# [情報] 饕饕 義大利麵 牛肉麵 0元
# /bbs/Lifeismoney/M.1706966162.A.04C.html
# [情報] 大潤發 名流150 ABS 61,687
# /bbs/Lifeismoney/M.1706967247.A.33A.html
# [情報] Hami-熊貓10%
# /bbs/Lifeismoney/M.1706989710.A.EEE.html
# [情報] 家樂福 AI迎龍表心意。活動頁面贈2點
# /bbs/Lifeismoney/M.1707008360.A.229.html
# [情報] UberEats大潤發多項優惠
# /bbs/Lifeismoney/M.1707018585.A.EB9.html
# [新聞] 明5日起國內汽油價格不調整柴油調降0.1元
# /bbs/Lifeismoney/M.1707019383.A.36B.html
# [情報] 台北市圖自助借書贈書活動
# /bbs/Lifeismoney/M.1707021482.A.58D.html
# [情報] iphone14pro手機殼+保護貼只要100
# /bbs/Lifeismoney/M.1707022848.A.975.html
# [情報] 台北西門站6號出口後方領$1發財金
# /bbs/Lifeismoney/M.1707041560.A.81A.html
# [情報] === 元月全台捐血贈品 === (1/26更新)
# /bbs/Lifeismoney/M.1704123061.A.9B5.html
# [公告] 板規(113.1.15修訂)暨違規公告區
# /bbs/Lifeismoney/M.1705326040.A.E50.html
# [公告] 贈送集中文
# /bbs/Lifeismoney/M.1692033175.A.D6D.html
# [公告] 未滿1元集點抽獎資訊集中文(置底)
# /bbs/Lifeismoney/M.1699811885.A.12A.html

# %%
# 走訪每一個 a link，整合網頁內文
for index, obj in enumerate(list_posts):
    res_ = req.get(obj['link'])
    soup_ = bs(res_.text, "lxml")
    
    # 去掉 div.article-metaline (作者、標題、時間…等)
    for div in soup_.select('div[class^="article-metaline"]'):
        div.decompose()
        
    # 去掉 div.push (推文: 推、→、噓) (判斷元素是否存在)
    if len( soup_.select('div.push') ) > 0:
        for div in soup_.select('div.push'):
            div.decompose()
    
    # 取得實際需要的內容 (類似 JavaScript 的 innerHTML)
    html = soup_.select_one('div#main-content').decode_contents()
    # html = str(soup_.select_one('div#main-content')) # 類似 JavaScript outerHTML
    
    # 預覽列表和內文
    print(obj['title'])
    print(obj['link'])
    print(html)
    print("=" * 50)
    
    # 整合到列表資訊的變數當中
    list_posts[index]['html'] = html


# 預覽所有結果
pprint(list_posts)
# Out:
# [花邊] Thibodeau：LeBron打了41分鐘，要讚揚他
# https://www.ptt.cc/bbs/NBA/M.1707036477.A.838.html
#
# Thibodeau：LeBron打了41分鐘，要讚揚他的身體狀態
#
# <a href="https://i.imgur.com/KUeoEnp.png" rel="noreferrer noopener nofollow" target="_blank">https://i.imgur.com/KUeoEnp.png</a>
# <div class="richcontent"><img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/KUeoEnpl.png?e=1707202945&amp;s=CXG6KnP-WWVoXyoLP4xYew"/></div>
# 虎撲02月04日訊 今日，尼克105-113主場不敵湖人，結束九連勝。賽後，尼克主帥Tom
# Thibodeau接受了採訪。
#
# 談到本場失利的原因，Thibodeau說：「阻攻是一個因素，AD（Anthony Davis）沒有得多
# 少分數但發揮出色，LeBron打得也一樣好。這些傢伙閱讀比賽形勢。LeBron打了41分鐘，
# 要讚揚他，他能保持那種級別的身體狀態。Davis很難應對。」
#
# <a href="https://m.hupu.com/bbs/624620384" rel="noreferrer noopener nofollow" target="_blank">https://m.hupu.com/bbs/624620384</a>
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 1.169.184.51 (臺灣)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/NBA/M.1707036477.A.838.html" rel="noreferrer noopener nofollow" target="_blank">https://www.ptt.cc/bbs/NBA/M.1707036477.A.838.html</a>
# </span><span class="f2">※ 編輯: Sessyoin (1.169.184.51 臺灣), 02/04/2024 16:49:06
# </span><div class="richcontent"><img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/IlPUgMWl.jpg?e=1707154263&amp;s=IPyQufcgGEoKGILDdIxoSQ"/></div>
# ==================================================
# [發錢] 新板主最後希望
# https://www.ptt.cc/bbs/NBA/M.1707037879.A.A9D.html
#
# 提醒一下再過不到7小時申請截止
#
# 有意願的趕快發文申請
# 當板主不會很難的 真的
#
# 再沒人出來本屆最後就會是
# <span class="f6 hl">羅森林</span><span class="f1 hl">VS</span><span class="f3 hl">馬來人</span>
#
# 終極二選一
#
# <a href="https://imgur.com/XMEaeKA" rel="noreferrer noopener nofollow" target="_blank">https://imgur.com/XMEaeKA</a>
#
# 推文時間戳記到2/4結束截止
#
# 截止前還是只有這兩人的話抽10個100P
#
# 有其他人拯救世界的話抽100個100P
#
#
# 摩多還押苦絕對不抽
#
# 你再洗我就送你進去
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 118.160.57.112 (臺灣)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/NBA/M.1707037879.A.A9D.html" rel="noreferrer noopener nofollow" target="_blank">https://www.ptt.cc/bbs/NBA/M.1707037879.A.A9D.html</a>
# </span><span class="f2">※ 編輯: ZIDENS (118.160.57.112 臺灣), 02/04/2024 17:11:58
# </span>沒有 兩人以上就是多選一
# 只有這兩個就一定會有一個是板主
# <div class="richcontent"><img alt="" loading="lazy" src="https://cache.ptt.cc/c/https/i.imgur.com/wBHW1DRl.jpg?e=1707161517&amp;s=K-S7DRXWzZffCFcCs5w5-A"/></div>因為程序上這個第四板主是"一定需要"的
# 如果是單人參選 信任投票沒過 那才是"那也沒辦法"
# 超過單人 就一定要選一個出來
# 老實說我是挺馬的
# 板主也共事過我是覺得沒什麼大問題
#
# 只是基於民意上提醒一下大家
# 沒人出來的話會是精彩的二選一
# 這樣講有失公允
# 畢竟羅森林沒當過板主
#
# 但我跟馬來共事過我覺得還好阿
# 至少多數決存在的情況下馬來是可控的
# ??????????????????????????????????
#
# 好吧你說的對
# ~~~
# ~~~
# 幫你嗨賴
# <span class="f2">※ 編輯: ZIDENS (118.160.57.112 臺灣), 02/04/2024 18:09:00
# </span>
# ==================================================
# [情報] Woj: Jarred Vanderbilt 右腳傷勢嚴重
# https://www.ptt.cc/bbs/NBA/M.1707040462.A.A5D.html
#
# 消息來源：
#
# <a href="https://twitter.com/wojespn/status/1753952122935066964" rel="noreferrer noopener nofollow" target="_blank">https://twitter.com/wojespn/status/1753952122935066964</a>
#
# Reporting on ABC NBA Countdown on Lakers forward Jarred Vanderbilt’s “
# significant” foot injury and concern he’s lost for season:
#
# 根據Woj今天最新的報導指出，
#
# Jarred Vanderbilt 面臨嚴重的右腳傷勢，本季甚至可能就此報銷
#
# 球團目前也在跟醫療專家進行諮詢，並且評估後續的處理狀況
#
#
#
# 短評或心得：近期逐漸找回狀態，可惜又受傷了
#
#
# --
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 150.117.39.40 (臺灣)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/NBA/M.1707040462.A.A5D.html" rel="noreferrer noopener nofollow" target="_blank">https://www.ptt.cc/bbs/NBA/M.1707040462.A.A5D.html</a>
# </span>
# ==================================================
# [公告] 板規10.1
# https://www.ptt.cc/bbs/NBA/M.1669686360.A.504.html
#
# <span class="hl">主旨</span>
#
# I  . NBA 板作為 NBA 群組之綜合性看板，歡迎<span class="hl">『具有想法且經整理過後並以之</span>
# <span class="hl">     與所有看板板友分享與討論為主要宗旨之內容』</span>之使用為最主要目的。
#
# II . 板友參與討論時，<span class="f3 hl">具有維護看板基本秩序與品質的責任與義務</span>，並且不應
#      主動挑起任何無意義爭端，使看板保有其最初看板討論功能。
#
# III. 看板板友在發表文章或使用推文系統時，必須確保其符合 NBA 板板旨，並
#      力求<span class="f3 hl">「內容與資訊之正確性」</span>
#
# IV . 板主以<span class="hl">「維護看板基本討論品質與秩序」</span>以及<span class="hl">「協助看板內容維持水準」</span>
#      為其最高指導原則，如有濫用板面或蓄意破壞秩序者，得以使用看板管理
#      工具為手段控制之(如刪文/劣退/水桶/鎖文等)
#
# V  . 本板<span class="f3 hl">以 NBA 之競技主體</span>為討論範圍，其他內容請盡量專板專用。
#      e.g. 影片→NBA_Film，閒聊→NBAEasyChat.....
#
# VI . NBA_Picket為本板之延伸公務看板, 兩板處分及發言權利連動, 此規定溯及既往.
#
#                            <span class="hl"> 內容管理</span>
# <span class="f2">※1.發文格式※</span>
# <span class="f5 hl">1.</span>Live：轉播文，<span class="f3 hl">每場比賽一篇為限</span>，須列出雙方先發名單或上場球員名單(英文名)。
#
#          1.以賽前半小時為準，先發者先贏。
#      　　2.重複者情於須於<span class="f3 hl">10分鐘內刪除，違者逕行刪文處理。</span>
#  　　　　3.<span class="f1 hl">禁止將轉播網站之連結修改營利。</span>請放上原本轉播的連結，違者板主可視
#            情況處分。
#          <span class="f6 hl">4.網址經他人檢舉證實為挖礦、病毒網址者，以鬧板論，板主應加重處置。</span>
# <span class="f6 hl"> </span>5.發文、推文張貼非法轉播連結者，板主應加以刪除並得視情節禁言處分。
#          6.發文、推文徵求非法轉播連結者，板主應加以刪除並得視情節禁言處分。
#
#
#   <span class="f5 hl">2.</span>Box：賽後數據，<span class="f3 hl">每場比賽以一篇為限</span>，板主得視情況決定留精美者或先發者
#
#          1.過往之戰績、數據、BOX、更改標題為<span class="f3 hl">[舊聞]，一日板面總數限定兩篇</span>
#            違者刪除。
#          2.BOX、Live兩分類不計入單日發文總數，但若發其他分類文章，則計入
#    　     （例如BOX發五篇，再發一篇討論則屬超貼，再發一篇LIVE則不算。）
#
#   <span class="f5 hl">3.</span>外絮：外電翻譯，發文者最少必須說明或翻譯文章內容大綱。
#
#          1.自我翻譯字數須滿足１５０字。<span class="f1 hl">需附上完整連結否則逕行刪除</span>。
#          2.譯文須符合原文，不得添加無關字詞，外絮以雜誌、地方報專欄的文章適用
#            須經基礎查證。
#          3.<span class="f3 hl">字數未足150字，請使用[情報]。</span>
# 　　 　　4.此分類須加註相關心得，個人意見可附於其中。
#
#   <span class="f5 hl">4.</span>專欄：由媒體專欄、運動網站、運動部落格文章，須滿足１５０字。
#
#  　　　　1.轉貼者須附上作者名，原文網址連結以及出處．<span class="f3 hl">每人每天限發一篇專欄。</span>
# <span class="f3 hl">(一篇限制包含文章自刪、被刪、轉文)</span>
# <span class="f3 hl"> </span>2.若為翻譯專欄，請盡量附上原文連結，供板友對照。
#          3.<span class="f3 hl">標題及內文</span><span class="f1 hl">球員姓名請一律使用英文姓名</span>，<span class="f1 hl">球隊名使用台灣譯名</span>
#           （若標題中譯名符合台灣通用譯名可不修改，由板主群判定。）
#
#   <span class="f5 hl">5.</span>情報：有關NBA新聞、每日戰績、電視轉播表、自行整理的NBA相關訊息。
#
#          1.<span class="f3 hl">每人每天限發一篇情報</span>，內容雷同者原則上只留一篇，以第一篇發表
#            時間為準，此分類須加註相關心得。
#            <span class="f3 hl"> (一篇限制包含文章自刪、被刪、轉文)</span>
# <span class="f3 hl"> </span>2.相關訊息須附完整來源網址，違者刪除。內容為翻譯新聞、引用外電新聞
#            等，請盡量附上原文連結，供板友對照。照片不能當消息來源，請注意。
#          3.新聞<span class="f3 hl">標題及內文</span><span class="f1 hl">球員姓名請一律使用英文姓名</span>，<span class="f1 hl">球隊名使用台灣譯名</span>
#           （若標題中譯名符合台灣通用譯名可不修改，由板主群判定。）
#          4.今日賽況總整理之文章，一日版面總數限兩篇，不計入單日發文總數。
#          5.本分類中國情報只開放正確度高的虎撲新聞
#          6.即使網址為台灣，內容提供來源為對岸且非虎撲新聞區之情報仍在禁止之列。
#          7.此分類不得用來偷渡無作者之新聞，而無作者定義由板規1-6-1定義。
#          8.每日數據文來源需有列出該球員當天表現的特殊事蹟、里程碑或紀錄。
#            <span class="f1 hl">(該場最高、今天最高...等等不在此列。)</span>
#          9.為促進分流，台灣新聞不能作為此分類來源，請使用新聞分類
#
#   <span class="f5 hl">6.</span>新聞：台灣新聞（於台灣具實體媒體，電視台、報紙等）
#
#          1.文章內需附上文章作者與文章連結，<span class="f3 hl">每人每天限發一篇新聞。</span>
# <span class="f1 hl">（文章作者需為真實姓名、筆名，體育中心不算文章作者。）</span>
# <span class="f3 hl">(一篇限制包含文章自刪、被刪、轉文)</span>
# <span class="f3 hl"> </span>2.內容雷同新聞原則上只留一篇，以第一篇發表時間為準。
#          3.須注意新聞之即時性與即期性，非當天新聞原則上禁止轉貼，但若為板上
#            尚無之消息，則可轉貼，須加註相關心得。
# 　　   　4.<span class="f3 hl">禁止「快訊」形式新聞，非台灣新聞者請使用情報分類。</span>
#          5.不具名新聞經查證出現標題殺人、造神、悖離原意等情事，將被刪除。
#
#   <span class="f5 hl">7.</span>討論：發表對NBA相關議題的各項討論
#
#          1.須遵守既有板規。
#          2.字數以150字以上為原則。
#          3.每人每天限發一篇討論。
# <span class="f3 hl">           (一篇限制包含文章自刪、被刪、轉文)</span>
#          4.<span class="f1 hl">依此分類偷渡其他分類規定下違規之文章，板主得加重水桶並刪除文章。</span>
# <span class="f5 hl">8.</span>花邊：較無關NBA的比賽賽事、但新聞內主角都是NBA的主角人物或相關情事，
#           則選用此分類。例如：退役球員健康狀況、球員夜生活夜店、NBA公益
#           活動、穿著造型流行、私下聚會等均可適用。
#
#          1.<span class="f1 hl">每日每人能貼一篇[花邊]。</span><span class="f3 hl">(一篇限制包含文章自刪、被刪、轉文)</span>
#          2.來源若為新聞/文章/專欄，<span class="f1 hl">則必須有記者或作者名，</span>違者刪文板規處
#            理。
#          3.來源若為推特/IG/臉書：
#           1) 來源須為球員，球團，記者，媒體等，<span class="f1 hl">不開放其他個人社群媒體。</span>
#              板主得視來源可靠性裁定是否保留該文。
#           2) <span class="f1 hl">必須附上內容說明，中英皆可，不可只附上網址</span>，違者刪文板規處
#              理。<span class="f3 hl">此類來源放寬150字限制。</span>
#           3) 來源需附上完整網址，否則刪除板規處分。
#          4.來源若為Youtube/Streamable:
#           1) 開放類似賽後訪問，如球員及教練訪問。
#           2) 不開放球員或球隊單場精華，集錦等影片。違者刪文板規處理。
#           3) 不開放Youtuber或個人經營頻道影片。違者刪文板規處理。
#           4) <span class="f3 hl">放寬150字限制。</span>
#           5) <span class="f1 hl">若發現為盜版連結或廣告嫌疑，板主應加以刪除並視情節劣退。</span>
#          5.為促進分流，台灣新聞不能作為此分類來源，請使用新聞分類
#
#   <span class="f5 hl">9.</span>回文：回文部分視為<span class="hl">不分類綜合討論</span>, 不受討論文單篇限制.
#  　　　   需遵守<span class="f3 hl">150字規範</span>及<span class="f3 hl">單日上限五篇限制</span>.
# 　　　　　情報與花邊之回文, 如附上連結以及提供相應主題之資訊.
#    　　　 視同情報與花邊, 得不受分類150字限制但是既然認定為情報與花邊
#           就會占用情報與花邊額度.
#
#  <span class="f5 hl">10.</span>推圖：推圖視為推文的一部分, 其文字與圖像內容受本板發言規範.
#           限制第二性徵裸露及粗言穢語, 每人每篇文章至多一圖, 超貼者視同
#           發文規範違規.(推圖是指藉由推文構成的圖像,而非圖片)
#
#
# 其它規範：1.<span class="f3 hl">「亦伸文」「黃邱倫文」「黃及人文」「張曜麟文」「動網文」</span>
# <span class="f3 hl">「basketball top 5文」「Haters文、籃球圈文」「鄭廷瑋文」</span>
# <span class="f3 hl">「梁偉銘文」「陳雍仁文」「廖柏璋文」「吳政紘文」「鍾東穎文」</span>
# <span class="f3 hl">「黎建忠文」AS文」</span>
# <span class="f3 hl"> 「Skip文」「Amico文」「Koha by Monet文」</span>
#
#             以上新聞記者與網站之撰文或經板友投票或連續違犯本板合理新
#             聞認定規定，<span class="f1 hl">禁止發布，違者刪除</span>。
#
#           2.<span class="f3 hl">「移花接木、翻譯錯誤記者文」</span>
#            1)如經查證、檢舉記者出的新聞有錯誤資訊，就醜一
#            2)<span class="f3 hl">醜一後</span>，公告記者姓名。
#              往後<span class="f3 hl">貼此位記者新聞，標題打上記者姓名</span>。
#            3)<span class="f1 hl">再次被抓到</span>資訊嚴重錯誤，就立即<span class="f1 hl">禁止此位記者的發文</span>。
#
#           3.承上，<span class="f3 hl">「張志宇文」「大濕兄聊NBA」「盧品青文」「林暐立文」</span>
# <span class="f3 hl">「陳元廷文」「Steam文」「唐嘉佑文」「邱晟軒文」「黃翊婷文」</span>
# <span class="f3 hl">「巫旻璇文」「黃嘉彣文」「陳國偉文」「張良瑜文」 「陳品翔文」
# </span><span class="f3 hl">            「陳冠宇文」</span>違反本板新聞專欄相關規定醜一。
#
#             新聞記者張志宇相關新聞即起需要在標題註明 CCY 違者刪除.
#             新聞記者盧品青相關新聞即起需要在標題註明 LPC 違者刪除.
#             新聞記者林瑋立相關新聞即起需要在標題註明 LWL 違者刪除.
#             新聞記者陳元廷相關新聞即起需要在標題註明 CYT 違者刪除.
#             新聞記者Steam相關新聞即起需要在標題註明 STE 違者刪除.
#             新聞記者唐嘉佑相關新聞即起需要在標題註明 TJY 違者刪除.
#             新聞記者邱晟軒相關新聞即起需要在標題註明 CCS 違者刪除.
#             新聞記者陳國偉相關新聞即起需要在標題註明 CGW 違者刪除.
#             新聞記者林保宏相關新聞即起需要在標題註明 LBH 違者刪除.
#             新聞記者黃翊婷相關新聞即起需要在標題註明 HYT 違者刪除.
#             新聞記者巫旻璇相關新聞即起需要在標題註明 WMX 違者刪除.
#             新聞記者黃嘉彣相關新聞即起需要在標題註明 HJW 違者刪除.
#             新聞記者張良瑜相關新聞即起需要在標題註明 CLY 違者刪除.
#             新聞記者Koha by Monet相關新聞即起需要在標題註明 KBM 違者刪除.
#             新聞記者陳品翔相關新聞即起需要在標題註明 CPX 違者刪除.
#             新聞記者陳冠宇相關新聞即起需要在標題註明 CGY 違者刪除.
#
#           4.<span class="f3 hl">「中國文章或香港文章」</span>
#            1)不論是使用外絮以外何種分類，
#            2)<span class="f1 hl">標題及文中的球員名稱請</span><span class="f3 hl">一律使用英文姓名</span><span class="f1 hl">，球隊名稱使用台灣譯名</span>
#            3)禁止在非台灣通用譯名後方，括弧加註英文名的發文方式。
#            4)若標題中譯名符合台灣通用譯名可不修改，由板主群判定。
#
#
#             舉例：米高佐敦譯名
#             修改=&gt;Michael Jordan             (O)
#                 =&gt;米高佐敦(Michael Jordan)   (X)
#
#
#           5.<span class="f3 hl">「祭品文」</span>
#
# 　　　　     請使用分類<span class="f1 hl">[祭品]、[發錢]</span>。
#        　　1)<span class="f1 hl">一人一日限定一篇，並須於一個禮拜內兌現</span>，<span class="f1 hl">發送至少</span>10<span class="f1 hl">位板友以上，</span>
#            2)若贈與內容過少，內容違反既有發文規則，板主視情節刪除或水桶劣退
#            3)發錢文最少需發送10位板友以上 最低100p
#              若未滿10位 則每位金額最低1000p
#            4)非[祭品]、[發錢] 分類之文章亦可發錢，內容管理受該分類規定限制
# 　　　　　　 金額受以上第3點限制，並且如無違規推文亦會被歸零。
#
#
#           6.<span class="f3 hl">「問卷文」</span>
#
#          　　問卷無私營利性質者（無商業性質）可另開分類[問卷]，亦得遵守以下規範
#
#      　　　1)請先至NBA_Picket提申請。
#            2)申請通過後，標題需以[問卷]作為分類。
#  　　　    3)一週內限一篇，所有板友共享此權利。
#  　　　    4)必須和ＮＢＡ或籃球、體育運動相關。
#  　　　    5)必須給予填答者Ｐ幣回饋。
#  　　　    6)勿請板主代為ＰＯ文。
#
#
#       　　7.<span class="f3 hl">「轉錄相關」</span>
#
#            　轉錄之文章，應與本板主題相關，轉錄文章數視為一日發文配額
#              <span class="f1 hl">請勿轉新聞。</span>
#
#
#           8.<span class="f3 hl">「影片分享相關規定」</span>
#
#            1) 相關影片分享
#               BOX文底下，請分享NBA官網連結，勿連結私人部落格其餘部分請洽
#               影片版討論。
#            2) 影片分享部落格
#               只能放在簽名檔，其他如推文或是文章內文有分享之影片連結，
#               皆以官網為主，以影片解說戰術之文章不再此限。
#
#
# <span class="f2">※2.文章砍除原則※</span>
#
#   2-1. 因發文規則： 包含分身,自刪,轉文,被板主砍文，1人1日 發文總數限制5篇
#    　　　　　　　　 情報、新聞未附連結、除情報與非水管花邊分類外未滿150字
#                     、討論串已S、標題格式錯誤、無關NBA文、簡體字過多。
#                   （簽名檔、標點符號、網址、數字不算字數，人名算一字、英文一個
#                     單字算一字。非各國語言現有單字不算字數，例：RRRRRR。
#                     如遇特殊情況，板主可判斷是否給予免罰，例如：大量數據文。
#                     其餘有規定字數之板規皆依此標準判定，不再另外補述。）
#   2-2. 個板閒聊文： 討論內容不足、無數據參考、無根據之閒聊文、心得薄弱等。
#   2-3. 偏頗比較文： 球員比較主體悉為主觀臆測, 證據薄弱, 以偏概全者。
#   2-4. 如果如果文： 加入過多假設性、不可能發生、如果成分高、臆測幻想文者。
#   2-5. 自創爭點文： 自創詭異爭點對任意球星進行貶抑性比較者.
#   2-6. 蓄意爭吵文： 發文攻訐, 模糊焦點, 證據薄弱, 以偏概全者。
#   2-7. 重複新聞文： 包含情報、台灣媒體、陸文(虎撲)等等出處，但內容雷同者。
#   2-8. 扭曲台媒文： 新聞或專欄過度腦補、扭曲事實、<span class="f6 hl">農場標題</span>、或搧風點火者。
#   2-9. 引戰反串文： 經舉報有抓到反串事證、語帶分化兩派球迷激化爭執者。
#   2-10.沒梗系列文： 系列文討論到後來已經沒梗還回文，後幾篇的討論性不足者。
#   2-11.仿標題系列： 仿同一頁面標題發文，想引起系列文鬧板者，板主得以退文。
#   2-12.跟風他板文： 由他板開始引發的系列文，如刻意在板上發文模仿視同鬧板。
#
#
#                              <span class="hl">治安管理</span>
# <span class="hl"> 原則</span>
#
#
#
# I   . 本板治安管理以原則為主判例為輔板規為底線, 板政以治安為第一考慮.
#
# II  . 基於減少使用者對板規的忌憚，引致發言的壓力，板主應該盡量在接獲
#       檢舉的時候才介入板面。看板檢舉一律透過<span class="hl">NBA_Picket</span>依據檢舉板板規
#  　　 相關規定受理，不收私信檢舉。
#
# III . 一旦接獲檢舉, 板主應盡可能悉數回覆於板面累積判例建立標準.
#
# IV  . 遇到治安問題或爭議, 板友應直接檢舉避免回應相關文章. 即使並非
#       始作俑者, 於回應時出現任何更多的治安問題者, 並不會酌情.
#
# V   . 治安問題的處理並非懲罰, 所有處理方式都以防止問題惡化和擴大作
#       為目標. 因此, 不論是禁回, 刪文, 鎖文, 低調, 歸零, 警告, 口頭警告,
#       還是水桶禁言, 都只是防止問題惡化的手段.
#
# VI  . 為避免看板公告淪為獨斷獨行, 鼓勵板友參與討論, 公告文下之違規
#       原則從輕認定, 涉及人身攻擊者除外.
#
# VII . 所有判決可供討論, 錯了就改, 板主不可能做什麼都是對的. 但是參
#       與判例討論仍需恪守板規及網路禮儀.
#
#
# VIII. 慣於鑽板規灰色地帶行攻訐奚落者` 主動挑起治安事端之始作俑者
#       認定為危險使用者, 板主會設法加以限制之.
#
# IX  . 非受本板治安相關原則判例與明文限定之違規, 板主盡可能善意解讀.
#
# <span class="f2">※3.發文/推文限制※</span>
#
#   1.原作者不得惡意竄改、刪除推文，必須尊重所有看板參與者之權益。
#
#   2.內容涉及鬧板行為之文章或推文（認定標準參考其他補充事項。)
#     針對與內文或推文串之內容行離題、釣魚引戰、挑起球迷對立、或披露個資，
#     若為文章則板主得劣文退回。
#    （註：情節嚴重或大量使用時，版主可視情況加重一犯。）
#     (以靈長類動物形容球員或動作視為3-2違規。)
#
#   3.不得以板面為工具，行惡意攻擊特定球員/球隊/板友之實，或挑起特定球迷間
#     之爭端．對於遭受人身攻擊之板友，若其原言論並無爭議，則板主有權加重攻
#     擊者之處分。
#    （註：情節嚴重或大量使用時，板主可視情況加重一犯。
#      <span class="f1 hl">崩潰</span>一詞，如<span class="f3 hl">指涉球迷或板友ID，亦屬於挑起爭端之範疇。)</span>
# <span class="f3 hl">  攻擊言論之細則如下</span>
#
#     硬限制(關鍵字出現即違規)：
#
#         (1)含有負面、惡意文字。
#            例如：<span class="f1 hl">屎、孬、賤、渣、姦、</span>...等等。
#
#         (2)含負面、不雅等人、事、物。
#             例如：<span class="f6 hl">強暴、垃圾、廢物、毒瘤、智障、低能、腦酸、無腦、腦洞、
# </span><span class="f6 hl">                  腦包、腦迷、腦殘、喜憨、腦癱、懶覺、龜頭(男性生殖器)、屄(女性
# </span><span class="f6 hl">                  生殖器)</span>...等等。
#
#         (3)指涉私人隱私、不實指控(若經球員或官方新聞證實則不再此限)。
#            例如：病史、醫療行為、犯罪行為...等等。
#
#     補充說明：
#
#         (1)若球員本身有相關負面要聞，則為可受公評的範圍，其下相關之暱稱可容
#            許之。
#
#         (2)板眾應酌量使用，若不斷重複、蓄意使用企圖引起爭端者，板主仍會根據
#            量來判定，而至於垃圾、廢物、懶覺等廣義以及涉及女性觀點之嚴重詞彙
#            ，仍會無視動機以行為處理。
#
#   4.請勿回文公告，對公告有問題可寄信或是po文討論，違規者板主得刪文/劣退之。
#     公告文下面推文違規，會以多一處犯規懲處。
#
#   5.文章內請勿使用注音文或過多簡體字，推文中如使用注音文或簡體字，超過三個字
#     予以水桶。
#
#   6.於同一篇文章進行噓文達5次以上，但BOX/LIVE文不受限。
# <span class="f1 hl">    註:以最後一噓的時間點為準。</span>
#
# 　7.看板禁止未尊重板友之個板文及自介文。違規文章版主得刪文或劣文退回，
#
#   8.禁止重複類似論述、跳針、洗板、大量洗同主題文章數。
#
#   9.討論串已Ｓ者，請勿回覆，回覆者即違規，板主有權刪除之。（仍可推文討論）
#
#  10.單一文章若同時犯三項以上版規（單篇文章累積三犯），則除砍除文章外，板主得退
# 　　文。此外，若違反站規(例如：公佈私信內容。)也比照辦理。
#
#  11.以負面或者羞辱詞彙點名板友：被點名板友得至檢舉板實名檢舉，並註明違反3-11。
#     板主群視狀況傳喚被檢舉人到案說明。
#
#  12.Live/Box文規定：從寬認定，但應以場上戰況及球員表現為主，引戰與攻擊球迷
#     或者板友，或離題行為嚴重者仍會辦理之，以質和量判定。
#      1) 硬限制攻擊/引戰<span class="f3 hl">球迷/板友</span>：一樣罰
#      2) 硬限制攻擊<span class="f5 hl">球員/球隊</span>：不建議使用，少量不罰，超過一日三次，三日五
#         次則處分。
#
# <span class="b1">附則</span>
#
#
# 　<span class="f2">※1.罰則※</span>
# <span class="f1 hl">刪除文章相關</span>
#
#     (1)違反板規一～三者(2)字數不足、超發者(3)錯誤發文格式者
#
# <span class="f1 hl">    違規次數與罰則計算</span>
#
#     一犯：水桶七日
# 　　二犯：水桶二週
# 　　三犯：水桶一個月
# 　　四犯：水桶半年
# 　　五犯：水桶二年
#     五犯以上：多一犯多一年。若遇嚴重違規者，板主得處以十年水桶。
#
#     <span class="f1 hl">累犯次數計算方式</span>
#
#     違規者於上次出桶後超過三個月未違規可消除違規乙次
#
#     板主水桶時，若查詢到違規者上次觸犯相同板規得加重一次(累犯)。
#
#     <span class="f3 hl">單日處分公告之同一違規人所有違規</span>
#
# 　　<span class="f3 hl">其禁言天數以當回累犯次數累加計</span>
#
# 　　即初犯者如一口氣犯下三次違規即禁言  7*3 = 21日 計一犯
#
#     季後初犯者則是                      7*2 = 14日 計一犯
#
#     三犯未消者如觸犯兩次違規則禁言   半年*2 = 1年  計四犯
#
#   　遇特殊情況，板主有權視情況調整罰則內容，但須於公告中說明．
#
#
#     <span class="f1 hl">輕微違規與板規灰色地帶罰則</span>
#
#     為協助板主快速維持看板治安
#
#     本板提供兩項工具作為使用
#
#
#
#
#     <span class="f1 hl">警告</span>
#
#     1. 違犯本板板規然情節不重者得處以警告
#
#     2. 經判定影響治安然難以歸類者得處以警告
#
#     3. 板主鑒於維護治安需要判定有必要強制冷靜者得處以警告
#
#     4. 警告之實質內涵為禁言三日強迫冷靜, 不計入本板累犯次數.
#
#     5. 警告不得單次連續處罰, 即: 沒有警告兩次禁言六天這種事
#
#     6. 為避免板主濫權, 警告亦須公告方得處置.
#
#     7. 除非執行板主擁有特殊理由, 警告之使用亦須經板主合議方可執行.
#
#     8. 縱有特殊理由, 警告之使用亦須由板主合議制追認, 如遭否決即須解除.
#
#
#
#
#
#     <span class="f1 hl">黃牌(舊口頭警告)</span>
#
#     作為治安管理原則 第 VIII 點之對應處置.
#
#     經認定難以歸類且有再犯之虞之實質看板治安影響者, 板主得合議以黃牌限制之.
#
#     細則:
#
#     1. 口頭警告對象匡列期為一年, 名單整理於精華區-板務-口頭警告專區.
#     2. 違規人受黃牌時不以實質禁言處分.
#     3. 受黃牌者在匡列期間於本板之所有敵意言論受限.
#        包含但不限於奚落` 生事` 訕笑` 貶抑` 攻訐` 譏諷` 指桑罵槐` 粗言穢語.
#        所有軟限制用詞亦屬之.
#        如往後再經檢舉, 板主得視對於看板治安之實質妨害程度緊縮尺度認定之.
#     4. 黃牌可連續處罰, 即受口頭警告者如再次違規, 除違規罰則外.
#        板主可延長其匡列期一年.
#     5. 黃牌計入本板累犯次數.
#     6. 受口頭警告處分者其違規法條適用本板累犯加重認定制.
#     7. 依板主判斷, 黃牌可與水桶處分併罰, 惟累犯次數僅採一次計.
#     8. 如宣告黃牌，板主須至SportBaduser板正式提出黃牌宣告.
# <span class="f2">※口頭警告在2024/1/20改為運動小組黃牌※</span>
#     根據國家體育場群組 <a href="/bbs/Sportcenter/M.1694695704.A.259.html" rel="noreferrer noopener nofollow" target="_blank">#1b0m4O9P (Sportcenter)</a>所述，口頭警告將會修正為黃牌條例
#     詳情可見該體育場群組公告
#     處罰對象類別主要包含:
#
#    （<span class="f6 hl">踩線仔</span>）發言內容長期悖離事實，干擾板主裁量，且有影響看板秩序之行為。
#    （<span class="f6 hl">鑽營鬼</span>）發言有長期鑽營板規灰色地帶，且有挑起紛爭之行為。
#    （<span class="f6 hl">指導棋</span>）長期使用偏離看板主旨文字，以私信或其他方式騷擾板主，且不受規勸。
#    （<span class="f6 hl">騷擾犯</span>）在看板多次發表偏離看板主旨文字，騷擾使用者，且不受規勸者。
#    （<span class="f6 hl">跳板人</span>）長期使用虛擬網路登入（VPN），且有影響看板秩序之行為。
#    （<span class="f6 hl">分靈體</span>）發言風格與其他列管者或黑名單近似，且皆有干擾看板秩序之行為。
#    （<span class="f6 hl">其他</span>）板主認定該位使用者之長期行為已有妨礙看板秩序之事實。
#    （<span class="f6 hl">調查</span>）使用者於帳號部調查多重帳號期間內，需接受組務黃牌。
#    （<span class="f6 hl">個案</span>）僅限組務管理人員提出。
#
#
#     <span class="f1 hl">衝突處理辦法</span>
#
#     爭議發言連帶導致推文板友大量爭執之文章板主得以透過刪鎖文終(中)止爭議.
#     推文歸零` 標記結案` 待證低調等皆屬相關回應措施.
#     此規範係為板面維護設立, 無涉原文違規與否.
#
# 　<span class="f2">※2.檢舉須知※</span>
#
#   1.需在三日內文章、推文，逾期不受理。
#   2.請至NBA_Picket板檢舉，發文格式請照檢舉板板規。
#   3.檢舉人不許修改事證中板友言行，否則視為誣告，亦不得威脅板主，
#     違者永不再受理相關檢舉。
#   4.違規文章如遭刪除, 推文底下檢舉得不受理. (釣魚保護條款)
#   5.判決流程
#
#                                      <span class="hl">意見不同→板主多數決←參考檢舉人意見</span>
#                                    ↗              ↓            ↑
#     <span class="hl">檢舉人發文檢舉→板主群審視內容 →取得共識→ </span><span class="f1 hl">公告結案 </span><span class="hl"> 公告24小時未到案</span>
#                                  ↑↘                            ↑
#                                  ↑  <span class="hl">仍有疑義→公告傳喚被檢舉人說明</span>
#                                  ↑                            ↙
#                                 <span class="hl">   ↖審視證據←被檢舉人到案說明</span>
#
#
# 　<span class="f2">※3.申訴須知※</span>
#
#       對於受罰判決不滿之板友，得於判決後七日內在<span class="hl">SP1_Basket</span>依申訴規定填寫[溝通]。
#       板主不接受站內信申訴。
#
#       若仍不滿申訴之結果，可上訴至籃球小組組務（SP2_Basket）
#
# <span class="b1">其他</span>
# <span class="f2">1.看板發文範圍</span>
#
#
#     本看板為NBA板(美國職業男籃討論版)其討論範圍如下：
#
# 　  <span class="f1 hl">「人」方面</span>
#   　分為球員、教練、老闆與高層．
#   　<span class="f3 hl">球員：</span>
# <span class="f3 hl">▉▉▉▉ </span><span class="f1 hl">▉▉▉▉▉▉▉ </span><span class="f2 hl">▉▉▉▉</span>
#         夏季聯盟     現役         退役
#
#          (新秀)
#
# 　  新秀：以夏季聯盟也列為現役球員討論，若目前不再夏季聯盟者，則不再討論之列，
#         　另外有其相關加入NBA之新聞為主也可參與NBA板討論．
#
#   　現役：以合約為標準，若未續約並且未在退役可討論之名單內則不在討論之列。
#         　但相同的是有其相關球隊感興趣之文章亦同為現役討論名單．
#
#   　因此相關亞錦賽、歐錦賽、美錦賽等賽事，以符合上述討論球員為準之球賽可討論．
# 　  此標準下，目前無合約者且未符合上述球員準則者，則不在討論之列，
#     但若是有其相關加入NBA之新聞則可討論之．
#
#   　<span class="f3 hl">教練：</span>
#   　教練同球員，惟夏季聯盟之教練不在討論之列．
#
# 　  <span class="f3 hl">老闆與高層：</span>以現役為準
#
#     <span class="f1 hl">「事」方面</span>
#
#     (一)、球場上的表現
#
#     (二)、球場外的軼事
#
#     (三)、是球員或球隊事件的討論與分析
#
#
#     <span class="f1 hl">其餘部分</span>
#     請洽相關看板，如NBA影片者：NBA_Film、球衣相關者：NBAJerseys
#     、台灣籃球者：basketballTW、笑話者：joke等。
#
#     <span class="f1 hl">球迷討論</span>
#
#     發文討論球迷言行、板友行為之相關文章，並不屬於本板討論範疇
#     相關討論球迷行為如何之文章，皆與以刪除或退回，並計入原有刪文罰則
#
#
# <span class="f2">※2.閒聊性質相關認定※</span>
#
# 　  基於公益大於私益原則，文章須符合公益，並且應避免主觀意見，
#     文章內容戲謔用詞過多、主觀成分過重、無實質內容者，
#     則視為閒聊性質，應以整體內容視之．
#
#     舉例說明：以某項看似客觀數據或是一段敘述做出結論，因此我認為
# 　　　　　　　某某球星是廢物或是某某球星&gt;某某小咖，此種私益行為未
# 　　　　　　　顧及到其他版友權益，會以閒聊文將之刪除。
#
# <span class="f2">※3.季後賽條款※</span>
#
#    時間:
#
#    每年球季季後賽期間第一場比賽開始至當季總冠軍出爐後一週
#
#    項目:
#
#    1.受板規2-1，1-9規定，未滿150字刪除者，另以退文處分.
#
#    2.違規行為判決時，以多一處犯規計算。
#      ex. 原本犯規為7天，季後賽違規變為7天*2=14天，仍計一犯。
#          若兩處違規，則為7天*3=21天，計一犯。
#
#    3.登入次數改為720次
#
# <span class="f2">※4.簽名檔相關※</span>
#
# 　採事後認定制
#   1.BOX、情報、新聞及外絮等翻譯非屬自我創作等轉貼文章，
#     不能放置簽名檔(屬於文章自我風格)外，
#   2.其餘如討論、心得、及專欄文(非轉錄者)可附上簽名檔。
#     但<span class="f3 hl">以附上他人ID形式之推文者則禁止</span>
#   3.引戰、違反板規三者禁止，違者刪除，內容違反板規者，適用於附則之懲處標準。
#   4.依20210623投票結果, 禁止本板板友使用宗教傳教相關圖文簽名檔發文.
#
# <span class="f2">※5.分身條款※</span>
#
#
#   分身與本尊視同相同ID，一律同罰。施行細則見下：
#
#       1.分身續犯本板板規者，板主可將所有帳號水桶至少十年以上時間。
#
#       2.本尊已入水桶，分身再度發言或檢舉他人，被發現者，所有帳號一起進桶，
#         且水桶時間以兩倍計算，並重新入桶。
#
#       3.分身之舉證須以短時間內至少IP兩處雷同，自行承認、網站提供之IP相同紀錄、
#         他板判決可納入參考，由板主認定．
#         如單純使用網站提供之IP相同紀錄檢舉，則至少需三次以上相同紀錄，但是否
#         送多重帳號查詢申請還是由板主決定。
#
#       4.已知分身且被本板公告者，日後不論本尊分身違規，一併執行罰則，不再另行舉
# 　　　　證是否為分身。
#
#       5.若受罰者濫用分身情況嚴重(多分身或不斷違規等情況)，將提交帳號部處理之。
#
#       6.於本板受禁言者無論本尊與分身, 禁止透過NBA_Picket檢舉他人, 如經查獲
#         適用本條款第一項.
#
#       7.受板務分身條款簡易處分者, 如明知判決無誤仍欺騙組長申訴經帳號部確認者.
#         視同分身續犯本板板規, 以分身條款第一項論處.
#
#
# <span class="f2">※6.板主權利及義務※</span>
#
# 　<span class="b1">總則</span>
# <span class="f1 hl">第一條  </span><span class="f2 hl">(規則依據)</span>
#
#   本規則依據
# ┌─────────────────────────────────────┐
# │ 文章代碼(AID): <a href="/bbs/Sportcenter/M.1351430125.A.FBC.html" rel="noreferrer noopener nofollow" target="_blank"><span class="hl">#1GZI_j-y </span>(Sportcenter)</a> [ptt.cc] [籃球群組]版主執行勤務規 │
# │ 文章網址: <span class="hl"><a href="https://www.ptt.cc/bbs/Sportcenter/M.1351430125.A.FBC.html" rel="noreferrer noopener nofollow" target="_blank">http://www.ptt.cc/bbs/Sportcenter/M.1351430125.A.FBC.html</a> </span>│
# └─────────────────────────────────────┘
#   之組規制定。
#
# <span class="f1 hl">第二條  </span><span class="f2 hl">(板主產生)</span>
# <span class="f1 hl">Ⅰ</span>NBA板設板主四人，人數之變動應應向組務板小組長申請辦理．
# <span class="f1 hl">Ⅱ</span>板主產生須依據NBA板板主選舉辦法
# ┌─────────────────────────────────────┐
# │ 文章代碼(AID): <a href="/bbs/Sportcenter/M.1336451838.A.E92.html" rel="noreferrer noopener nofollow" target="_blank"><span class="hl">#1FgAB-wI </span>(Sportcenter)</a> [ptt.cc] [籃球群組公告] NBA板板主 │
# │ 文章網址: <span class="hl"><a href="https://www.ptt.cc/bbs/Sportcenter/M.1336451838.A.E92.html" rel="noreferrer noopener nofollow" target="_blank">http://www.ptt.cc/bbs/Sportcenter/M.1336451838.A.E92.html</a> </span>│
# └─────────────────────────────────────┘
#   由板友投票選出。
# <span class="f1 hl">Ⅲ</span>本板板主採任期制, 任期一年一任，一次選出一到兩位新版主，每年NBA熱身賽開始前
#   以及全明星賽周上任，上述月份前一個月1日起開始遴選新任板主。
# <span class="f1 hl">Ⅳ</span>原板主得連選連任。
# <span class="f1 hl">Ⅴ</span>本板板主為任期制，如板主經罷免卸任、因故請辭或遭解職，遞補板主以任完板主任
#   期為限，任期屆滿仍可重新參選。
# <span class="f1 hl">Ⅵ</span>如該任板主任期剩餘未滿一個月，則不另外補選，由剩餘板主任事，待任期期滿再
#   行選出下一屆板主。
#
#
# <span class="f1 hl">第三條  </span><span class="f2 hl">(板主職務)</span>
#
#   板主職務如下並由板主群自行分配職務範圍：
#   一、日常事項
#       (一) 整理精華區
#       (二) 處理版友檢舉
#       (三) 刪除不當文章(違反板規)，視情況退回該文章與發表人，如有必要應以說明．
#       (四) 樂透之開設
#
#   二、不定事項
#       (一) 申訴處理
#       (二) 判例解釋及板規之修正
#       (三) 辦理相關活動
#
# <span class="f1 hl">第四條</span><span class="f2 hl">  (自律條款)</span>
# <span class="f1 hl">I  .</span>板主不應違犯板規，如有違犯，經板友提醒後即應中止違規行為並設法加以補救。
# <span class="f1 hl">II .</span>任一板主如與板友產生言語交鋒並衍生後續相互檢舉事宜者, 當事板主應迴避處置.
# <span class="f1 hl">III.</span>任一板主如與板友產生相互檢舉事宜, 裁決板主應盡可能從輕認定雙方.
# <span class="f1 hl">IV .</span>板主如察覺判決有誤應即刻補救. 除補救外亦應針對受影響板友實質補償.
#     實質補償範圍包括:文章P幣賠償` 原文救回與公告改判並致歉.
#
# <span class="f1 hl">第五條  </span><span class="f2 hl">(緊急事項)</span>
# <span class="f1 hl">I  .</span>板主為因應特殊事件，得修改板規、設置特別條款，須經所有板主群同意．
# <span class="f1 hl">II .</span>修改板規、設置特別條款時，須參考民意，如遇強烈爭議，應重新擬定之．
#
# <span class="f1 hl">第六條</span>　<span class="f2 hl">(爭議處理)</span>
#
# 板主群權責各自獨立，裁決以民主表決為原則，遇有爭議情況，得洽第三方共同協商之，
# 板主群處理板務，亦應以互信合作為原則，並定時交換彼此意見．
#
# <span class="f1 hl">第七條</span> <span class="f2 hl">(板主罷免)</span>
#
#   版主有第五條及第六條職務上之疏失時，板友得依組規，
#   Sportcenter精華區
#   2. ◆ 國家體育場之運動規則
#   2. ◆ 群組法規
#   2. ◆ 罷免規定
#   申請罷免之
#
#
# 板規歷來沿革
# 2011/08/17 v1.0
# 2011/10/13 v1.1
# 2011/12/13 v1.2
# 2012/02/09 v2.0
# 2012/05/11 v2.1
# 2012/08/01 v3.0
# 2012/09/10 v3.0
# 2013/01/08 v4.0
# 2013/02/02 v4.1
# 2013/02/28 v4.2
# 2013/07/04 v5.0
# 2014/01/04 v5.1
# 2014/11/12 v5.2 （譯名條款新增）
# 2016/06/29 v6.0  合併各項增修板規
# 2016/12/02 v6.1  取消警告制度，修改累犯計算方式
# 2017/05/24 v6.1  修改進桶次數為違規次數
# 2017/09/17 v6.2  合併及修正重疊板規，禁止農場標題
# 2019/04/08 v6.3  修改過去投票通過增加、廢除款項，增加板規細項說明
# 2019/05/24 v6.4  增設過去曾公告之條款及字數計算詳細說明。
# 2019/10/05 v6.5  增設禁止非法轉播連結及投票通過之條款。
# 2019/11/29 v6.6  增設禁止Haters、籃球圈網站文章及修改投票通過之板規3-3修正
# 2019/12/16 v6.7  增設禁止basketball top 5網站文章及1-11、1-12條款。
# 2019/12/31 v6.8  增設禁止鄭廷瑋新聞，及增設偷渡無作者新聞條款。
# 2021/05/24 v6.9  增設禁止梁偉銘新聞。
# 2021/06/02 v7.0  花邊板規修正，開放社群媒體及Youtube。
# 2021/06/04 v7.1  因應NBA_Picket板設立，修訂檢舉條例以及申訴條例。
# 2021/06/07 v7.2  增設廖柏璋新聞醜一條款。
# 2021/06/09 v7.3  1. 改錯字
#                  2. 移除投票等板規變動原因連結僅保留結論縮減板面.
#                  3. 調換原板規1 2 大項
#                  4. 補充看板主旨與實質管理原則
#                  5. 加入0609裁罰相關板規修訂投票結果與試辦板規無心之失條款.
#                  6. 新增非祭品發錢文之發錢規範 緣由<a href="/bbs/NBA_Picket/M.1623069442.A.C11.html" rel="noreferrer noopener nofollow" target="_blank">#1WlXC2mH (NBA_Picket)</a>
#                  7. 季後賽條款納入
# 2021/06/20 v7.4  板規1-5補充, 即1-5-6 限制內容來源為中國非虎撲新聞區之情報。
#                  檢舉須知新增判決流程
#                  申訴須知新增判例討論辦法
# 2021/06/24 v7.5  新增板規附則4-4 禁止本板板友使用宗教傳教相關圖文簽名檔發文
#                  新增口頭警告處分細則 4~7條
#                  新增板規附則5-6 違規使用者及其分身透過匿名檢舉之處罰細則.
#                  新增板規附則2-4 釣魚保護條款.
#                  新增板規附則6-2 板主任期制遴選辦法
#                  新增衝突處理辦法.
#                  配合檢舉板板規補充兩板發言權利連動事項.
# 2021/06/27 v7.6  新增板主自律條款4-4
#                  新增申訴辦法勞役替代條款
# 2021/06/29 v7.7  試辦板規禁止徵求違法連結上線
# 2021/07/05 v7.8  新增分身條款第七條, 欺詐行為處罰.
# 2021/07/10 v7.9  補充發文規範板規1-9 回文規範.
# 2021/07/12 v8.0  改錯字與修改板規2-1說明 非水管花邊納入.
# 2021/07/13 v8.1  因連續標題殺人新聞醜二, 禁止陳雍仁新聞發布.
#                  因應板主可能會使用推圖提醒釣魚與違規文章
#                  頒布板規1-10 推圖規範.
# 2021/07/17 v8.2  增設禁止廖柏璋新聞.
# 2021/07/23 v8.3  待證` 結案及歸零作為衝突處理辦法之作法補充.
# 2021/08/17 v8.4  合併板規球員比較文及張飛岳飛文為偏頗比較文
#                  增設自創爭點文
# 2021/07/13 v8.1  因連續標題殺人新聞醜二, 禁止陳雍仁新聞發布.
#                  因應板主可能會使用推圖提醒釣魚與違規文章
#                  頒布板規1-10 推圖規範.
# 2021/07/17 v8.2  增設禁止廖柏璋新聞.
# 2021/07/23 v8.3  待證` 結案及歸零作為衝突處理辦法之作法補充.
# 2021/08/17 v8.4  合併板規球員比較文及張飛岳飛文為偏頗比較文
#                  增設自創爭點文
#                  新聞記者鍾東穎醜一
# 2021/08/19 v8.5  新聞記者張志宇醜一
# 2021/08/31 v8.6  新聞記者黎建忠醜一
# 2021/10/18 v8.7  新聞記者游郁香醜一
#                  新聞記者盧品青醜一
# 2021/11/01 v8.8  新聞記者林瑋立醜一
# 2021/11/22 v8.9  增設禁止吳政紘新聞。
# 2021/12/09       增加簡體字規定。
# 2021/12/14       增加禁止鍾東穎新聞。
# 2021/12/31 v9.0  因應SP1_Basket成立，修正申訴以及問卷文規定
# 2022/01/17       新聞記者陳元廷/Steam醜一
# 2022/01/19       BOX/LIVE條款訂定罰則
# 2022/02/08       禁止黎建忠新聞
# 2022/02/10       硬限制字詞補充
# 2022/04/15 v10.0 取消軟限制以及相關條文修正
# 2022/05/02       修正消息來源，須完整網址。
# 2022/06/02       依據 <a href="/bbs/SP1_Basket/M.1654139298.A.483.html" rel="noreferrer noopener nofollow" target="_blank">#1Yc2cYI3 (SP1_Basket)</a> 問卷文規定修正
# 2022/06/21       修正3-11實名檢舉，取消無心之失以及勞役代替
# 2022/07/08       唐嘉佑文標題需加TJY
# 2022/07/26        "腦殘"入硬限制。
# 2022/08/02       邱晟軒文標題需加CCS
# 2022/10/31 v10.01李則緯文標題需加LZW、YT花邊字數放寬、五噓&amp;虎撲修正。
#                  林保宏文標題需加LBH、林偉帆文禁發
#                  游郁香文禁發
#                  黃翊婷文標題需加HYT
# 2022/11/29 v10.1 提高每日數據文門檻，降低Live文門檻
# 2022/12/17 v10.11集中台灣新聞至新聞分類
# 2022/12/31       巫旻璇文標題需加WMX
# 2023/1/30        黃嘉彣文標題需加HJW
# 2023/02/07       陳國偉文標題需加CGW、李則緯禁發
# 2023/03/14       張良瑜文標題需加CLY
# 2023/08/18       Koha by Monet文標題需加KBM
# 2023/10/30       陳品翔文標題需加CPX
# 2023/11/06       新增"腦癱"為硬限制
# 2023/12/06       陳冠宇文標題需加CGY
# 2024/01/12       擴大來源黑名單至美國記者/媒體人
# 2024/01/20       Koha by Monet禁發 黃牌相關條例
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 71.232.216.168 (美國)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/NBA/M.1669686360.A.504.html" rel="noreferrer noopener nofollow" target="_blank">https://www.ptt.cc/bbs/NBA/M.1669686360.A.504.html</a>
# </span><span class="f2">※ 編輯: EZ78 (71.232.216.168 美國), 11/29/2022 09:48:15
# </span><span class="f2">※EZ78 於 11/29/2022 09:49:45 將推薦值歸零
# </span><span class="f2">※ 編輯: EZ78 (71.232.216.168 美國), 12/18/2022 02:01:33
# </span><span class="f2">※ 編輯: EZ78 (124.218.32.104 臺灣), 12/31/2022 02:30:31
# </span><span class="f2">※ 編輯: EZ78 (71.232.216.168 美國), 01/30/2023 18:11:18
# </span><span class="f2">※ 編輯: EZ78 (71.232.216.168 美國), 02/08/2023 03:42:18
# </span><span class="f2">※ 編輯: EZ78 (71.232.216.168 美國), 02/08/2023 03:45:47
# </span><span class="f2">※ 編輯: EZ78 (71.232.216.168 美國), 03/03/2023 07:31:30
# </span><span class="f2">※ 編輯: EZ78 (71.232.216.168 美國), 03/14/2023 18:41:46
# </span><span class="f2">※ 編輯: EZ78 (123.193.63.116 臺灣), 08/18/2023 17:44:27
# </span><span class="f2">※ 編輯: EZ78 (98.217.185.18 美國), 10/30/2023 14:32:47
# </span><span class="f2">※ 編輯: EZ78 (98.217.185.18 美國), 11/06/2023 15:37:29
# </span><span class="f2">※ 編輯: EZ78 (98.217.185.18 美國), 12/06/2023 17:49:31
# </span><span class="f2">※ 編輯: EZ78 (98.217.185.18 美國), 01/12/2024 14:21:01
# </span><span class="f2">※ 編輯: EZ78 (98.217.185.18 美國), 01/12/2024 14:21:38
# </span><span class="f2">※ 編輯: EZ78 (98.217.185.18 美國), 01/20/2024 22:12:29
# </span><span class="f2">※ 編輯: EZ78 (98.217.185.18 美國), 01/20/2024 22:13:20
# </span><span class="f2">※ </span><span class="f2 hl">jerryyuan</span><span class="f2">:轉錄至看板 Lakers</span>                                     01/22 13:16
#
# ==================================================
# [情報] 2023-24賽季 例行賽賽程 (一月、二月上半)
# https://www.ptt.cc/bbs/NBA/M.1703474570.A.5DA.html
#
# <span class="hl">┌─────────────────────────────────────┐</span>
# <span class="hl">│</span><span class="b4 hl"> 　　　　　　　　　　　　電視轉播表　查詢網址　　　　  　　　　　  　　　 </span><span class="hl">│</span>
# <span class="hl">└─────────────────────────────────────┘</span>
#
# 　　Elta 體育臺 　<a href="https://eltaott.tv/mod/program_detail" rel="noreferrer noopener nofollow" target="_blank">https://eltaott.tv/mod/program_detail</a>
#
# 　　緯來體育臺　　<a href="http://sport.videoland.com.tw/chn/jc.asp" rel="noreferrer noopener nofollow" target="_blank">http://sport.videoland.com.tw/chn/jc.asp</a>
#
# 　　LINE TODAY  　<a href="https://today.line.me/tw/v2/article/gJ0eXN" rel="noreferrer noopener nofollow" target="_blank">https://today.line.me/tw/v2/article/gJ0eXN</a>
#
# 　　官網完整賽程　<a href="https://www.nba.com/schedule" rel="noreferrer noopener nofollow" target="_blank">https://www.nba.com/schedule</a>
#
#
#
#
#
#
#
# ┌─────────────────────────────────────┐
# │<span class="b1 hl">  2023–24 例行賽  電視轉播表 (台灣時間)  </span><span class="b3 hl"> ABC </span><span class="b5 hl"> ESPN </span><span class="b2 hl"> TNT </span><span class="b1 hl"> </span><span class="b6 hl"> 愛爾達 </span><span class="b4 hl"> 緯來 </span>│
# └─────────────────────────────────────┘
# <span class="f6">┌───────────┬────────────┬────────────┐</span>
# <span class="f6">│ </span>01月01日（一）       <span class="f6">│</span> 01月02日（二）         <span class="f6">│</span> 01月03日（三）         <span class="f6">│</span>
# <span class="f6">├───────────┼────────────┼────────────┤</span>
# <span class="f6">│</span> 04:00   老鷹    巫師 <span class="f6">│</span> 04:00   灰狼    尼克   <span class="f6">│</span> 08:00   公牛    七六人 <span class="f6">│</span>
# <span class="f6">│ </span>08:00  <span class="b6 hl"> 湖人  </span><span class="b4 hl">  鵜鶘 </span><span class="f6">│</span> 08:30   騎士    暴龍   <span class="f6">│</span> 09:00  <span class="b6 hl"> 馬刺    灰熊   </span><span class="f6">│</span>
# <span class="f6">│ </span>08:00   籃網    雷霆 <span class="f6">│</span> 09:00   活塞    火箭   <span class="f6">│</span> 09:00   籃網    鵜鶘   <span class="f6">│</span>
# <span class="f6">│ </span>08:00   青賽    馬刺 <span class="f6">│</span> 09:00   溜馬    公鹿   <span class="f6">│</span> 09:00   青賽    雷霆   <span class="f6">│</span>
# <span class="f6">│ </span>09:00 D<span class="b4 hl"> 國王    灰熊 </span><span class="f6">│</span> 10:00   黃蜂    金塊   <span class="f6">│</span> 11:00  <span class="b4 hl"> 魔術    勇士   </span><span class="f6">│</span>
# <span class="f6">│ </span>09:00   魔術    太陽 <span class="f6">│</span> 10:00   拓荒者  太陽   <span class="f6">│</span> 11:00   黃蜂    國王   <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>10:00   獨行俠  爵士   <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>11:30  <span class="b6 hl"> 熱火  </span><span class="b4 hl">  快艇   </span><span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">└───────────┴────────────┴────────────┘</span>
#
# ┌─────────────────────────────────────┐
# │<span class="b1 hl">  2023–24 例行賽  電視轉播表 (台灣時間)  </span><span class="b3 hl"> ABC </span><span class="b5 hl"> ESPN </span><span class="b2 hl"> TNT </span><span class="b1 hl"> </span><span class="b6 hl"> 愛爾達 </span><span class="b4 hl"> 緯來 </span>│
# └─────────────────────────────────────┘
# <span class="f6">┌───────────┬────────────┬────────────┐</span>
# <span class="f6">│ </span>01月04日（四）       <span class="f6">│</span> 01月05日（五）         <span class="f6">│</span> 01月06日（六）         <span class="f6">│</span>
# <span class="f6">├───────────┼────────────┼────────────┤</span>
# <span class="f6">│</span> 08:00   巫師    騎士 <span class="f6">│</span> 08:30 <span class="b2 hl"> </span><span class="b6 hl"> 公鹿    馬刺   </span><span class="f6">│</span> 08:00   爵士    青賽   <span class="f6">│</span>
# <span class="f6">│</span> 08:00   公鹿    溜馬 <span class="f6">│</span> 11:00 <span class="b2 hl"> </span><span class="b6 hl"> 金塊  </span><span class="b4 hl">  勇士   </span><span class="f6">│</span> 08:00   老鷹    溜馬   <span class="f6">│</span>
# <span class="f6">│</span> 08:30   雷霆    老鷹 <span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 08:30   雷霆    籃網   <span class="f6">│</span>
# <span class="f6">│</span> 09:00   籃網    火箭 <span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 08:30   巫師    騎士   <span class="f6">│</span>
# <span class="f6">│</span> 09:00   暴龍    灰熊 <span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 08:30 <span class="b5 hl"> </span><span class="b4 hl"> 尼克    七六人 </span><span class="f6">│</span>
# <span class="f6">│</span> 09:00   鵜鶘    灰狼 <span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 09:00   黃蜂    公牛   <span class="f6">│</span>
# <span class="f6">│</span> 09:30 <span class="b3 hl"> </span> 公牛    尼克 <span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 09:00   灰狼    火箭   <span class="f6">│</span>
# <span class="f6">│</span> 09:30  拓荒者  獨行俠<span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 09:00  <span class="b6 hl"> 快艇    鵜鶘   </span><span class="f6">│</span>
# <span class="f6">│</span> 10:00  <span class="b6 hl"> 快艇    太陽 </span><span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 09:30   拓荒者  獨行俠 <span class="f6">│</span>
# <span class="f6">│</span> 10:00   活塞    爵士 <span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 10:00   魔術    金塊   <span class="f6">│</span>
# <span class="f6">│</span> 11:00 <span class="b5 hl"> </span><span class="b4 hl"> 熱火    湖人 </span><span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 10:00   熱火    太陽   <span class="f6">│</span>
# <span class="f6">│</span> 11:00   魔術    國王 <span class="f6">│</span> <span class="f6"> </span> <span class="f6">│</span> 11:00   活塞    勇士   <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> 11:00 <span class="b5 hl"> </span><span class="b4 hl"> 灰熊    湖人   </span><span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> 11:00   暴龍    國王   <span class="f6">│</span>
# <span class="f6">└───────────┴────────────┴────────────┘</span>
#
# ┌─────────────────────────────────────┐
# │<span class="b1 hl">  2023–24 例行賽  電視轉播表 (台灣時間)  </span><span class="b3 hl"> ABC </span><span class="b5 hl"> ESPN </span><span class="b2 hl"> TNT </span><span class="b1 hl"> </span><span class="b6 hl"> 愛爾達 </span><span class="b4 hl"> 緯來 </span>│
# └─────────────────────────────────────┘
# <span class="f6">┌───────────┬────────────┬────────────┐</span>
# <span class="f6">│ </span>01月07日（星期日）   <span class="f6">│ </span>01月08日（一）         <span class="f6">│ </span>01月09日（二）         <span class="f6">│</span>
# <span class="f6">├───────────┼────────────┼────────────┤</span>
# <span class="f6">│ </span>08:00  <span class="b4 hl"> 青賽    溜馬 </span><span class="f6">│ </span>02:00   馬刺    騎士   <span class="f6">│ </span>08:00   公牛    黃蜂   <span class="f6">│</span>
# <span class="f6">│ </span>08:00   尼克    巫師 <span class="f6">│ </span>04:00   拓荒者  籃網   <span class="f6">│ </span>08:00   青賽    溜馬   <span class="f6">│</span>
# <span class="f6">│ </span>08:30   爵士  七六人 <span class="f6">│ </span>07:00   老鷹    魔術   <span class="f6">│ </span>08:00   雷霆    巫師   <span class="f6">│</span>
# <span class="f6">│ </span>09:00  <span class="b6 hl"> 公鹿  </span><span class="b4 hl">  火箭 </span><span class="f6">│ </span>07:00   鵜鶘    國王   <span class="f6">│ </span>08:30   火箭    熱火   <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>08:30   灰狼    獨行俠 <span class="f6">│ </span>09:00   爵士    公鹿   <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>09:00   活塞    金塊   <span class="f6">│ </span>11:30  <span class="b6 hl"> 太陽  </span><span class="b4 hl">  快艇   </span><span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>09:00   灰熊    太陽   <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>09:30   暴龍    勇士   <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>10:30  <span class="b6 hl"> 快艇  </span><span class="b4 hl">  湖人   </span><span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│   </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">└───────────┴────────────┴────────────┘</span>
#
# ┌─────────────────────────────────────┐
# │<span class="b1 hl">  2023–24 例行賽  電視轉播表 (台灣時間)  </span><span class="b3 hl"> ABC </span><span class="b5 hl"> ESPN </span><span class="b2 hl"> TNT </span><span class="b1 hl"> </span><span class="b6 hl"> 愛爾達 </span><span class="b4 hl"> 緯來 </span>│
# └─────────────────────────────────────┘
# <span class="f6">┌───────────┬────────────┬────────────┐</span>
# <span class="f6">│ </span>01月10日（三）       <span class="f6">│ </span>01月11日（四）         <span class="f6">│ </span>01月12日（五）         <span class="f6">│</span>
# <span class="f6">├───────────┼────────────┼────────────┤</span>
# <span class="f6">│ </span>08:00   國王    活塞 <span class="f6">│ </span>08:00   灰狼    青賽   <span class="f6">│ </span>03:00   籃網    騎士   <span class="f6">│</span>
# <span class="f6">│ </span>08:00   灰狼    魔術 <span class="f6">│ </span>08:00   國王    黃蜂   <span class="f6">│ </span>        ＠巴黎         <span class="f6">│</span>
# <span class="f6">│ </span>08:30   拓荒者  尼克 <span class="f6">│ </span>08:00   馬刺    活塞   <span class="f6">│ </span>08:30 <span class="b2 hl"> </span><span class="b6 hl"> 青賽    公鹿   </span><span class="f6">│</span>
# <span class="f6">│ </span>09:30  <span class="b6 hl"> 灰熊  獨行俠 </span><span class="f6">│ </span>08:00   巫師    溜馬   <span class="f6">│ </span>09:00   拓荒者  雷霆   <span class="f6">│</span>
# <span class="f6">│ </span>11:30  <span class="b4 hl"> 暴龍    湖人 </span><span class="f6">│ </span>08:30   七六人  老鷹   <span class="f6">│ </span>09:30   尼克    獨行俠 <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>08:30   雷霆    熱火   <span class="f6">│ </span>11:00 <span class="b2 hl"> </span><span class="b6 hl"> 太陽  </span><span class="b4 hl">  湖人   </span><span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>09:00   火箭    公牛   <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>09:30 <span class="b3 hl"> </span><span class="b6 hl"> 鵜鶘  </span><span class="b4 hl">  勇士   </span><span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>11:00 <span class="b5 hl"> </span> 金塊    爵士   <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span>11:30   暴龍    快艇   <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">└───────────┴────────────┴────────────┘</span>
#
# ┌─────────────────────────────────────┐
# │<span class="b1 hl">  2023–24 例行賽  電視轉播表 (台灣時間)  </span><span class="b3 hl"> ABC </span><span class="b5 hl"> ESPN </span><span class="b2 hl"> TNT </span><span class="b1 hl"> </span><span class="b6 hl"> 愛爾達 </span><span class="b4 hl"> 緯來 </span>│
# └─────────────────────────────────────┘
# <span class="f6">┌───────────┬────────────┬────────────┐</span>
# <span class="f6">│ </span>01月13日（六）       <span class="f6">│ </span>01月14日（星期日）     <span class="f6">│ </span>01月15日（一）         <span class="f6">│</span>
# <span class="f6">├───────────┼────────────┼────────────┤</span>
# <span class="f6">│ </span>08:30   火箭    活塞 <span class="f6">│ </span>08:00   火箭    青賽   <span class="f6">│ </span>04:30   溜馬    金塊   <span class="f6">│</span>
# <span class="f6">│ </span>08:30   溜馬    老鷹 <span class="f6">│ </span>08:30   巫師    老鷹   <span class="f6">│ </span>07:00   黃蜂    熱火   <span class="f6">│</span>
# <span class="f6">│ </span>08:30 <span class="b5 hl"> </span> 國王  七六人 <span class="f6">│ </span>09:00   尼克    灰熊   <span class="f6">│ </span>08:00   國王    公鹿   <span class="f6">│</span>
# <span class="f6">│ </span>09:00   魔術    熱火 <span class="f6">│ </span>09:00  <span class="b6 hl"> 勇士  </span><span class="b4 hl">  公鹿   </span><span class="f6">│ </span>08:00  <span class="b4 hl"> 快艇    灰狼   </span><span class="f6">│</span>
# <span class="f6">│ </span>09:00  <span class="b4 hl"> 勇士    公牛 </span><span class="f6">│ </span>09:00   魔術    雷霆   <span class="f6">│ </span>10:00  <span class="b6 hl"> 太陽    拓荒者 </span><span class="f6">│</span>
# <span class="f6">│ </span>09:00  <span class="b6 hl"> 快艇    灰熊 </span><span class="f6">│ </span>09:30   鵜鶘    獨行俠 <span class="f6">│ </span> <span class="f6">│</span>
# <span class="f6">│ </span>09:00   拓荒者  灰狼 <span class="f6">│ </span>09:30   公牛    馬刺   <span class="f6">│ </span> <span class="f6">│</span>
# <span class="f6">│ </span>09:00   黃蜂    馬刺 <span class="f6">│ </span>10:30 D<span class="b4 hl"> 湖人    爵士   </span><span class="f6">│ </span> <span class="f6">│</span>
# <span class="f6">│ </span>10:30   暴龍    爵士 <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span>11:00 <span class="b5 hl">D</span><span class="b4 hl"> 鵜鶘    金塊 </span><span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">└───────────┴────────────┴────────────┘</span>
#
# ┌─────────────────────────────────────┐
# │<span class="b1 hl">  2023–24 例行賽  電視轉播表 (台灣時間)  </span><span class="b3 hl"> ABC </span><span class="b5 hl"> ESPN </span><span class="b2 hl"> TNT </span><span class="b1 hl"> </span><span class="b6 hl"> 愛爾達 </span><span class="b4 hl"> 緯來 </span>│
# └─────────────────────────────────────┘
# <span class="f6">┌───────────┬────────────┬────────────┐</span>
# <span class="f6">│ </span>01月16日（二）       <span class="f6">│ </span>01月17日（三）         <span class="f6">│</span> 01月18日（四）         <span class="f6">│</span>
# <span class="f6">├───────────┼────────────┼────────────┤</span>
# <span class="f6">│ </span>02:00   火箭  七六人 <span class="f6">│ </span>08:30 <span class="b2 hl"> </span><span class="b6 hl"> 金塊  </span><span class="b4 hl">  七六人 </span><span class="f6">│</span> 08:00   灰狼    活塞   <span class="f6">│</span>
# <span class="f6">│ </span>03:30   鵜鶘  獨行俠 <span class="f6">│ </span>10:00   國王    太陽   <span class="f6">│</span> 08:30   魔術    老鷹   <span class="f6">│</span>
# <span class="f6">│ </span>04:00   魔術    尼克 <span class="f6">│ </span>11:00 <span class="b2 hl"> </span><span class="b6 hl"> 雷霆    快艇   </span><span class="f6">│</span> 08:30   馬刺    青賽   <span class="f6">│</span>
# <span class="f6">│ </span>04:00   活塞    巫師 <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> 08:30 <span class="b5 hl"> </span> 公鹿    騎士   <span class="f6">│</span>
# <span class="f6">│ </span>04:30 <span class="b2 hl"> </span> 馬刺    老鷹 <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> 08:30   火箭    尼克   <span class="f6">│</span>
# <span class="f6">│ </span>07:00 <span class="b2 hl"> </span><span class="b6 hl"> 勇士    灰熊 </span><span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> 08:30   熱火    暴龍   <span class="f6">│</span>
# <span class="f6">│ </span>08:00   公牛    騎士 <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> 09:00   黃蜂    鵜鶘   <span class="f6">│</span>
# <span class="f6">│ </span>08:30   熱火    籃網 <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> 09:30 <span class="b3 hl"> </span><span class="b6 hl"> 獨行俠 </span><span class="b4 hl"> 湖人   </span><span class="f6">│</span>
# <span class="f6">│ </span>08:30   青賽    暴龍 <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> 延賽(*) 勇士    爵士   <span class="f6">│</span>
# <span class="f6">│ </span>10:00   溜馬    爵士 <span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> 11:00   籃網    拓荒者 <span class="f6">│</span>
# <span class="f6">│ </span>11:30  <span class="b6 hl"> 雷霆  </span><span class="b4 hl">  湖人 </span><span class="f6">│ </span><span class="f6"> </span> <span class="f6">│</span> <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span> ＊客隊一位助教因心臟病 <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span>   發而過世，補賽日期將 <span class="f6">│</span>
# <span class="f6">│ </span> <span class="f6">│        </span> <span class="f6">│</span>   另行公佈。           <span class="f6">│</span>
# <span class="f6">└───────────┴────────────┴────────────┘</span>
#
# ┌─────────────────────────────────────┐
# │<span class="b1 hl">  2023–24 例行賽  電視轉播表 (台灣時間)  </span><span class="b3 hl"> ABC </span><span class="b5 hl"> ESPN </span><span class="b2 hl"> TNT </span><span class="b1 hl"> </span><span class="b6 hl"> 愛爾達 </span><span class="b4 hl"> 緯來 </span>│
# └─────────────────────────────────────┘
# <span class="f6">┌───────────┬────────────┬────────────┐</span>
# <span class="f6">│ </span>01月19日（五）       <span class="f6">│ </span>01月20日（六）         <span class="f6">│</span> 01月21日（星期日）     <span class="f6">│</span>
# ...
#           '<span class="b2 hl"> </span> 單項挑戰賽     <span class="f6">│</span>\n'
#           '<span class="f6">│ </span>09:30   馬刺  獨行俠 <span class="f6">│ '
#           '</span><span class="f6"> </span> <span class="f6">│</span> <span '
#           'class="f6">│</span>\n'
#           '<span class="f6">│ </span>10:00   國王    金塊 <span class="f6">│ '
#           '</span><span class="f6"> </span> <span class="f6">│ '
#           '</span>02月19日（一）         <span class="f6">│</span>\n'
#           '<span class="f6">│ </span>10:00   活塞    太陽 <span class="f6">│ '
#           '</span><span class="f6"> </span> <span class="f6">│</span> <span '
#           'class="f6">│</span>\n'
#           '<span class="f6">│ </span>10:00   湖人    爵士 <span class="f6">│ '
#           '</span><span class="f6"> </span> <span class="f6">│ </span>09:30 '
#           '<span class="b2 hl"> </span> 全明星賽       <span class="f6">│</span>\n'
#           '<span class="f6">│ </span>11:00 <span class="b5 hl"> </span><span '
#           'class="b6 hl"> 快艇  </span><span class="b4 hl">  勇士 </span><span '
#           'class="f6">│ </span><span class="f6"> </span> <span class="f6">│ '
#           '</span>        西部    東部   <span class="f6">│</span>\n'
#           '<span class="f6">└───────────┴────────────┴────────────┘</span>\n'
#           '＊時間表可能隨時出現更動，請以官方的公佈為準。\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 180.74.68.8 (馬來西亞)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1703474570.A.5DA.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1703474570.A.5DA.html</a>\n'
#           '</span><span class="f2">※ 編輯: laptic (180.74.69.169 馬來西亞), '
#           '01/07/2024 10:33:20\n'
#           '</span><span class="f2">※ 編輯: laptic (180.74.219.219 馬來西亞), '
#           '01/18/2024 01:32:08\n'
#           '</span><span class="f2">※ 編輯: laptic (180.74.219.241 馬來西亞), '
#           '01/18/2024 19:02:52\n'
#           '</span><span class="f2">※ 編輯: laptic (118.101.168.36 馬來西亞), '
#           '01/20/2024 00:08:48\n'
#           '</span><span class="f2">※ 編輯: laptic (118.101.170.238 馬來西亞), '
#           '01/26/2024 07:36:19\n'
#           '</span><span class="f2">※ 編輯: laptic (180.74.219.148 馬來西亞), '
#           '01/27/2024 20:46:07\n'
#           '</span><span class="f2">※ 編輯: laptic (180.74.217.178 馬來西亞), '
#           '02/02/2024 09:28:54\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1703474570.A.5DA.html',
#   'title': '[情報] 2023-24賽季 例行賽賽程 (一月、二月上半)'},
#  {'html': '\n'
#           '根據板規附則6.第二條.III\n'
#           '\n'
#           '本板板主採任期制, 任期一年一任，一次選出一到兩位新版主，每年NBA熱身賽開始前\n'
#           '以及全明星賽周上任，上述月份前一個月1日起開始遴選新任板主。\n'
#           '\n'
#           '目前板主還有一名明星賽任期的缺額，故預計在2/19徵選出一名新的板主\n'
#           '\n'
#           '本次選舉預計:\n'
#           '\n'
#           '1.選出1位新板主\n'
#           '\n'
#           '2.參選人若不足2位的話則安排信任投票，需得到6成(含)以上同意票才當選\n'
#           '\n'
#           '3.本次板主任期為 2023年2月19日至 2024-25 NBA明星賽\n'
#           '\n'
#           '----------------以下參考小艾克過往參選文-------------------\n'
#           '2023 明星周板主選舉重點提醒\n'
#           '1. 即日起 ~ 02/04 ：4日翻5日午夜12點截止，2週接受參選文，標題請用[參選]。\n'
#           '2.         02/05 ：期間有發參選文，Tab標籤都可看見，現任板主02/05發投票文。\n'
#           '3. 02/05 ~ 02/19 ：兩週時間投票，投票結果公布後，最高票當選板主。\n'
#           '\n'
#           '\n'
#           '請參選者填完必填資料後，請花心思概述一下第五點內容，越詳細越好，感謝。\n'
#           '參選限制：沒有退文、登入次數1000、發文次數至少30篇、在本板無長於兩年之水桶紀錄\n'
#           '(總計)或分身帳號違規紀錄、在本板發文次數至少20篇\n'
#           '\n'
#           '\n'
#           '板主選舉公告依據\n'
#           '<a '
#           'href="https://www.ptt.cc/bbs/Sportcenter/M.1336451838.A.E92.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/Sportcenter/M.1336451838.A.E92.html</a>  '
#           '(Sportcenter)\n'
#           '<a href="https://www.ptt.cc/bbs/NBA/M.1624591947.A.0FE.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1624591947.A.0FE.html</a>          '
#           '(NBA)\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '------------------------- 發參選文請由下方內容開始複製-----------------------\n'
#           '\n'
#           'NBA板板主選舉參選文件\n'
#           '1.參選人基本資料：（可至主選單：(U)ser-&gt;(I)nfo查詢）\n'
#           '擔任板主：\n'
#           '登入次數：\n'
#           '有效文章：\n'
#           '劣文數：\n'
#           '\n'
#           '\n'
#           '2.參選人（含同一人持有之所有帳號）違規紀錄：\n'
#           'a.兩年內是否曾受站規處分而被停權或宣告褫奪公權？      （請至ID_Muliti、ID_Fina\n'
#           'nce、Violation等看板查詢）\n'
#           '（  ）否      （  ）是，請說明：\n'
#           '\n'
#           '\n'
#           'b.是否曾受組規處分？例如曾在組務各看板被水桶？\n'
#           '  是否曾在國家體育場任板主被免職或被罷免成功？\n'
#           '（  ）否      （  ）是，請說明：\n'
#           '\n'
#           '\n'
#           'c.兩年內是否曾在籃球群組受半年以上之水桶處分？\n'
#           '是否曾在同一看板被板規處分達兩次以上？\n'
#           '（  ）否      （  ）是，請列出紀錄並說明之：\n'
#           '\n'
#           '\n'
#           'd.是否曾在國家體育場發表鼓吹仇恨、對立之言論，或使用容易引發對立之暱稱、簽名檔\n'
#           '或名片檔，或是否持有以特定球隊、球員為攻擊對象的帳號？\n'
#           '（  ）否      （  ）是，請說明：\n'
#           '\n'
#           '\n'
#           'e.若有其他足以影響使用者對板主信賴之紀錄者，請在此提出並說明之。\n'
#           '（  ）否      （  ）是，請說明：\n'
#           '\n'
#           '\n'
#           '3.參選人過去管理看板或網路討論區的經歷，或其他參與本站公共事務之經驗\n'
#           '\n'
#           '\n'
#           '4.參選人與NBA的關係、看球經驗或理解程度（簡單說明即可，不必寫論文）\n'
#           '\n'
#           '\n'
#           '5.參選人之政見、對NBA板的期望及其他問題。\n'
#           '[請簡述你的個人特質]\n'
#           '[對於現在的NBA板有什麼看法?]\n'
#           '[你理想中的NBA板長什麼樣子?]\n'
#           '[你準備多努力讓NBA板朝向你理想的樣貌前進?]\n'
#           '[每日上站時間與管板時間?]\n'
#           '[本板罰則對你來說過重與過輕者請各舉列一處並提出你個人的理想作法.]\n'
#           '[基於任何原因如果特定板友對你抱持敵意你會怎麼處理?]\n'
#           '[自認沒錯的判決如果經申訴被組務打回你會怎麼看待及回應?]\n'
#           '[你會如何履行你的政見? 如果政見難以履行你怎麼做?]\n'
#           '[如順利上任, 你開不開樂透?]\n'
#           '[你想投入板主一職的動機是什麼？]\n'
#           '[你看到了板上需要改變的問題是什麼？會怎麼改？] \u3000\n'
#           '[若上任了，短程規劃是什麼？]\n'
#           '[若上任了，遠程規劃是什麼？]\n'
#           '[若可以給你修板規，你會更改/新增什麼，才會覺得更合理更好？]\n'
#           '[如果沒有選上, 做為曾參選過板主的板友你會怎麼使用本板?]\n'
#           '[上面十六點無法闡明我的熱情，我想自由發揮]  (若無可略)\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 98.217.185.18 (美國)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1705632851.A.439.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1705632851.A.439.html</a>\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1705632851.A.439.html',
#   'title': '[公告] 明星賽期板主徵選'},
#  {'html': '\n'
#           '<span class="b4 hl">  Eastern Conference                    '
#           '</span><span class="f4">◣</span> <span class="f4 b4 hl"> '
#           '</span>ATLANTIC <span class="f6 b6 hl"> </span>CENTRAL <span '
#           'class="f1 b1 hl"> </span>SOUTHEAST\n'
#           '<span class="f4 b7">   EASTERN      Ｗ Ｌ  PCT   GB  CONF  DIV  HOME  '
#           'ROAD L10 STR   PF    PA  DIFF</span>\n'
#           '1<span class="f4 b4 hl"> </span>Celtics     －37 12 .755   --  25-6 '
#           '11-1  22-3  15-9 7-3 L1 120.1 111.1 <span class="f1 hl">  '
#           '9.0</span>\n'
#           '2<span class="f6 b6 hl"> </span><span class="f1 hl">Bucks       '
#           '</span>－33 16 .673  4.0 24-12  9-7  21-5 <span class="f1 '
#           'hl">12-11</span> 6-4 W1 124.0 119.9   4.1\n'
#           '3<span class="f6 b6 hl">1</span><span class="f1 hl">Cavaliers   '
#           '</span><span class="f1 hl">▲</span>31 16 .660  5.0 20-10  7-4  17-8 '
#           '<span class="f1 hl"> 14-8</span> 9-1 W5 114.3 109.7   4.7\n'
#           '4<span class="f4 b4 hl">1</span><span class="f2 hl">Knicks      '
#           '</span><span class="f2 hl">▼</span>32 18 .640  5.5 22-10  6-3 <span '
#           'class="f2 hl"> 18-6</span> 14-12 9-1 L1 115.0 <span class="f1 '
#           'hl">109.3</span>   5.8\n'
#           '5<span class="f4 b4 hl"> </span><span class="f2 hl">76ers       '
#           '</span>－30 18 .625  6.5 <span class="f2 hl">19-12</span> <span '
#           'class="f2 hl"> 5-4</span> <span class="f2 hl"> 17-7</span> 13-11 '
#           '5-5 L1 119.1 113.3   5.8\n'
#           '6<span class="f6 b6 hl"> </span>Pacers      －27 23 .540 10.5 21-13  '
#           '9-2 16-10 11-13 4-6 L3 <span class="f1 hl">124.4</span> 122.8   '
#           '1.5\n'
#           '－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－\n'
#           '7<span class="f1 b1 hl"> </span>Heat        －26 23 .531 11.0 19-15 '
#           '10-2 13-11 13-12 3-7 W2 110.4 111.4  -0.9\n'
#           '8<span class="f1 b1 hl"> </span>Magic       －26 23 .531 11.0 17-13  '
#           '6-4  15-7 11-16 5-5 W2 111.6 110.8   0.7\n'
#           '9<span class="f6 b6 hl"> </span><span class="f2 hl">Bulls       '
#           '</span>－23 27 .460 14.5 14-17  3-6 <span class="f2 '
#           'hl">14-12</span>  9-15 5-5 L1 111.1 112.6  -1.6\n'
#           '0<span class="f1 b1 hl"> </span><span class="f1 hl">Hawks       '
#           '</span>－22 27 .449 15.0 13-20  6-5 <span class="f1 hl">12-13</span> '
#           '10-14 6-4 W4 121.2 123.4  -2.2\n'
#           '───────────────────────────────────────\n'
#           ' <span class="f4 b4 hl"> </span><span class="f1 hl">Nets        '
#           '</span>－20 28 .417 16.5 <span class="f1 hl">14-14</span> <span '
#           'class="f1 hl"> 2-5</span> 12-13 <span class="f1 hl"> 8-15</span> '
#           '4-6 W1 114.6 115.4  -0.8\n'
#           ' <span class="f4 b4 hl"> </span>Raptors     －17 31 .354 19.5 11-21 '
#           '0-11 10-13  7-18 2-8 L1 114.3 117.0  -2.7\n'
#           ' <span class="f1 b1 hl"> </span>Hornets     －10 37 .213 26.0  7-22  '
#           '3-6  5-18  5-19 2-8 L6 <span class="f2 hl">108.5</span> 120.4 <span '
#           'class="f2 hl">-11.9</span>\n'
#           '<span class="f1 b1 hl"> </span>Wizards     － 9 39 .188 27.5  6-28 '
#           '2-10  3-20  6-19 2-8 L2 114.8 <span class="f2 hl">123.7</span>  '
#           '-9.0\n'
#           ' <span class="f6 b6 hl"> </span>Pistons     － 6 42 .125 30.5  5-24 '
#           '1-10  4-22  2-20 3-7 L2 112.9 122.5  -9.7\n'
#           '               Ｗ-Ｌ= -31\n'
#           '<span class="f6 hl">     vs West: 112-143 .439</span>\n'
#           '<span class="b1 hl">  Western Conference                    '
#           '</span><span class="f1">◣</span> <span class="f2 b2 hl"> '
#           '</span>NORTHWEST <span class="f5 b5 hl"> </span>PACIFIC <span '
#           'class="f3 b3 hl"> </span>SOUTHWEST\n'
#           '<span class="f1 b7">   WESTERN      Ｗ Ｌ  PCT   GB  CONF  DIV  HOME  '
#           'ROAD L10 STR   PF    PA  DIFF</span>\n'
#           '1<span class="f2 b2 hl"> </span>Thunder     －34 15 .694   -- 21-11 '
#           '10-3  19-6  15-9 7-3 W2 <span class="f1 hl">120.6</span> 112.5 '
#           '<span class="f1 hl">  8.0</span>\n'
#           '2<span class="f2 b2 hl"> </span>Timberwolves－34 15 .694   --  23-8  '
#           '6-2  18-5 16-10 6-4 L1 113.0 <span class="f1 hl">107.0</span>   '
#           '5.9\n'
#           '3<span class="f5 b5 hl"> </span>Clippers    －32 15 .681  1.0 21-11  '
#           '7-3  19-4 13-11 8-2 W2 118.5 112.0   6.4\n'
#           '4<span class="f2 b2 hl"> </span>Nuggets     －34 16 .680  0.5 18-11  '
#           '3-5  20-4 14-12 7-3 W1 114.8 110.7   4.1\n'
#           '5<span class="f5 b5 hl"> </span><span class="f1 hl">Kings       '
#           '</span>－29 19 .604  4.5 18-13  6-5  14-8 <span class="f1 '
#           'hl">15-11</span> 6-4 W2 118.5 117.5   1.1\n'
#           '6<span class="f5 b5 hl"> </span>Suns        －28 21 .571  6.0 17-14  '
#           '5-7 14-11 14-10 7-3 L1 116.9 114.7   2.2\n'
#           '－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－－\n'
#           '7<span class="f3 b3 hl"> </span>Pelicans    －28 21 .571  6.0 20-17  '
#           '7-6 14-10 14-11 5-5 W2 116.4 112.9   3.6\n'
#           '8<span class="f3 b3 hl"> </span><span class="f2 hl">Mavericks   '
#           '</span>－26 23 .531  8.0 18-18  7-5 <span class="f2 hl">14-13</span> '
#           '12-10 3-7 L2 118.2 118.8  -0.6\n'
#           '9<span class="f5 b5 hl"> </span><span class="f1 hl">Lakers      '
#           '</span>－26 25 .510  9.0 18-16  6-4  17-8 <span class="f1 hl"> '
#           '9-17</span> 6-4 W2 116.1 117.1  -1.0\n'
#           '0<span class="f2 b2 hl"> </span>Jazz        －24 26 .480 10.5 12-18  '
#           '4-6  15-7  9-19 4-6 L3 117.6 120.0  -2.3\n'
#           '───────────────────────────────────────\n'
#           ' <span class="f3 b3 hl"> </span>Rockets     －23 25 .479 10.5 16-12  '
#           '7-3  18-9  5-16 4-6 W1 113.9 112.3   1.5\n'
#           ' <span class="f5 b5 hl"> </span><span class="f2 hl">Warriors    '
#           '</span>－21 25 .457 11.5 12-19  3-8 13-13 <span class="f2 hl"> '
#           '8-12</span> 4-6 L1 119.0 118.8   0.1\n'
#           ' <span class="f3 b3 hl"> </span>Grizzlies   －18 31 .367 16.0 12-23  '
#           '6-6  5-18 13-13 4-6 L4 <span class="f2 hl">107.2</span> 112.7  '
#           '-5.4\n'
#           ' <span class="f2 b2 hl"> </span>TrailBlazers－15 34 .306 19.0  6-27  '
#           '1-8  9-13  6-21 5-5 L1 108.5 116.7  -8.2\n'
#           ' <span class="f3 b3 hl"> </span><span class="f2 hl">Spurs       '
#           '</span>－10 40 .200 24.5  7-21  1-8 <span class="f2 hl"> '
#           '5-21</span>  5-19 3-7 L4 112.3 <span class="f2 hl">120.9</span> '
#           '<span class="f2 hl"> -8.5</span>\n'
#           '               Ｗ-Ｌ= 31\n'
#           '<span class="f6 hl">     vs East: 143-112 .561</span>\n'
#           '\n'
#           '\n'
#           '───────────────────────────────────────\n'
#           '<span class="f6 hl">兩隊勝率相同時</span> <span class="f3 '
#           'hl">三隊以上勝率相同時</span> <span class="f5 hl">分區 #7-10 附加賽 (Apr. '
#           '17-20)</span>\n'
#           '<span class="f6 hl">Ⅰ</span>彼此對戰之勝率          <span class="f3 '
#           'hl">Ⅰ</span>為分組第一者優先   <span class="f3 hl">例行#7</span> '
#           '──┐            <span class="f0 hl">GMT+8</span>\n'
#           '<span class="f6 hl">Ⅱ</span>為分組第一者優先        <span class="f3 '
#           'hl">Ⅱ</span>彼此對戰之勝率              G1├─ <span class="f6 '
#           'hl">季後#7</span>\n'
#           '<span class="f2 hl">Ⅲ</span>對戰同分組之勝率（<span '
#           'class="hl">DIV欄</span>；處於同分組時適用）  <span class="f3 hl">例行#8</span> '
#           '──┘\n'
#           '<span class="f2 hl">Ⅳ</span>對戰同分區之勝率（<span '
#           'class="hl">CONF欄</span>）\n'
#           '<span class="f2 hl">Ⅴ</span>對戰同分區季後賽球隊之勝率                   <span '
#           'class="f3 hl">例行#9</span> ──┐\n'
#           '<span class="f2 hl">Ⅵ</span>對戰不同分區季後賽球隊之勝率                          '
#           'G2├─┐\n'
#           '<span class="f2 hl">Ⅶ</span>淨分差（<span '
#           'class="hl">DIFF欄</span>）                             <span '
#           'class="f3 hl">例行#10</span>──┘G3├─ <span class="f6 hl">季後#8</span>\n'
#           'Source: <a href="https://www.nba.com/standings" rel="noreferrer '
#           'noopener nofollow" '
#           'target="_blank">https://www.nba.com/standings</a> <span class="f2 '
#           'hl">G1負者</span>─┘\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 42.79.147.219 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1707020302.A.0DC.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1707020302.A.0DC.html</a>\n'
#           '</span><span class="f2">※ 編輯: guardyo (42.79.147.219 臺灣), '
#           '02/04/2024 12:18:24\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1707020302.A.0DC.html',
#   'title': '[情報] NBA Standings (Feb. 04, 2024)'},
#  {'html': '\n'
#           '決戰西一\n'
#           "請到 NBA 板 按'f'參與樂透!\n"
#           '\n'
#           '2/5西一決定戰\n'
#           '1.灰狼 2.雷霆 3.快艇 4.金塊\n'
#           '可能會有BUG哪隊是絕對不可能登頂的\n'
#           '<span class="f1 hl">請謹慎評估</span>\n'
#           '\n'
#           '\n'
#           '一張 100 Ptt幣 (平民級)\n'
#           '樂透結束時間: 02/05/2024 07:00:52 Mon\n'
#           '<span class="f2">※ 編輯: ZIDENS (118.160.57.112 臺灣), 02/04/2024 '
#           '12:23:32\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1707020589.A.928.html',
#   'title': '[公告] NBA 板 開始舉辦樂透!'}]

# %% [markdown]
# # 思考
# - 如何取得**多個分頁**的內容?
#   - 觀察分頁數字在網址的呈現方式
#   - 將觀察到的分頁數字嵌入對應的網址當中

# %%
# 清空放置列表資訊的變數
list_posts.clear()

# 起始頁數
init_page = 6503

# 最新頁數
latest_page = 6504

# 在已經知道分頁數的情況下
for page in range(init_page, latest_page + 1):
    
    # 取得新聞列表
    url = f"https://www.ptt.cc/bbs/NBA/index{page}.html" 

    # 用 requests 的 get 方法把網頁抓下來
    res = req.get(url) 

    # 指定 lxml 作為解析器
    soup = bs(res.text, "lxml") 
    
    # 取得 列表 的文字與超連結
    for a in soup.select('div.r-ent div.title a[href]'):
        # 加入列表資訊
        list_posts.append({
            'title': a.get_text(),
            'link': 'https://www.ptt.cc' + a['href']
        })
        
# 走訪每一個 a link，整合網頁內文
for index, obj in enumerate(list_posts):
    res_ = req.get(obj['link'])
    soup_ = bs(res_.text, "lxml")

    # 去掉 div.article-metaline (作者、標題、時間…等)
    for div in soup_.select('div[class^="article-metaline"]'):
        div.decompose()
        
    # 去掉 div.push (推文: 推、→、噓) (判斷去掉元素是否存在)
    if len( soup_.select('div.push') ) > 0:
        for div in soup_.select('div.push'):
            div.decompose()

    # 取得實際需要的內容 (類似 JavaScript 的 innerHTML)
    html = soup_.select_one('div#main-content').decode_contents()

    # 整合到列表資訊的變數當中
    list_posts[index]['html'] = html

        
# 預覽所有結果
pprint(list_posts)
# Out:
# []
